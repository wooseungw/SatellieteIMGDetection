# %%
import os
import shutil

# 기존 클래스 ID에서 새 클래스 ID로 매핑
class_mapping = {
    0: 0,  # motorboat -> ship(s)
    1: 0,  # sailboat -> ship(s)
    2: 0,  # tugboat -> ship(L)
    3: 1,  # barge -> ship(L)
    4: 0,  # fishing boat -> ship(s)
    5: 1,  # ferry -> ship(L)
    6: 1,  # container ship -> ship(L)
    7: 1,  # oil tanker -> ship(L)
    8: 1,  # drill ship -> ship(L)
    9: 1,  # warship -> ship(L)
}

# 라벨과 이미지 원본 디렉터리
original_labels_dir = './dataset2/labels'
original_images_dir = './dataset2/images'

# 새로 복사할 디렉터리
new_labels_dir = './datasets/labels'
new_images_dir = './datasets/images'

# 폴더가 없는 경우 생성
os.makedirs(new_labels_dir, exist_ok=True)
os.makedirs(new_images_dir, exist_ok=True)

# 라벨 파일을 업데이트하여 새 디렉터리에 저장하는 함수
def update_label_file(file_path, new_file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    new_lines = []
    for line in lines:
        parts = line.strip().split()
        original_class_id = int(parts[0])
        if original_class_id in class_mapping:
            new_class_id = class_mapping[original_class_id]
            parts[0] = str(new_class_id)
            new_line = ' '.join(parts)
            new_lines.append(new_line)
        else:
            print(f"경고: 클래스 ID {original_class_id}가 매핑에 없습니다.")
    
    # 새 라벨 파일로 저장
    os.makedirs(os.path.dirname(new_file_path), exist_ok=True)  # 하위 디렉터리 생성
    with open(new_file_path, 'w') as file:
        file.write('\n'.join(new_lines))

# 라벨 파일 업데이트 및 복사
for root, dirs, files in os.walk(original_labels_dir):
    for filename in files:
        if filename.endswith('.txt'):
            old_file_path = os.path.join(root, filename)
            # 기존 경로에서 새로운 라벨 경로로 변환 (dataset/labels/train, dataset/labels/val 등)
            relative_path = os.path.relpath(old_file_path, original_labels_dir)
            new_file_path = os.path.join(new_labels_dir, relative_path)
            update_label_file(old_file_path, new_file_path)
            print(f"{new_file_path} 업데이트 완료")

# 이미지 파일 복사
for root, dirs, files in os.walk(original_images_dir):
    for filename in files:
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # 이미지 확장자에 따라 필터링
            old_file_path = os.path.join(root, filename)
            # 기존 경로에서 새로운 이미지 경로로 변환 (dataset/images/train, dataset/images/val 등)
            relative_path = os.path.relpath(old_file_path, original_images_dir)
            new_file_path = os.path.join(new_images_dir, relative_path)
            os.makedirs(os.path.dirname(new_file_path), exist_ok=True)  # 하위 디렉터리 생성
            shutil.copy2(old_file_path, new_file_path)
            print(f"{new_file_path} 이미지 복사 완료")
# Out:
# ./datasets/labels\train\OBJ00032_PS3_K3_AIDATA0585.txt 업데이트 완료
# ./datasets/labels\train\OBJ00036_PS3_K3_AIDATA0585.txt 업데이트 완료
# ./datasets/labels\train\OBJ00059_PS3_K3_AIDATA0587.txt 업데이트 완료
# ./datasets/labels\train\OBJ00068_PS3_K3_AIDATA0587.txt 업데이트 완료
# ./datasets/labels\train\OBJ00111_PS3_K3A_AIDATA0589.txt 업데이트 완료
# ./datasets/labels\train\OBJ00115_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00116_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00117_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00118_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00121_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00123_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00124_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00125_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00126_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\train\OBJ00134_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00137_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00138_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00139_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00140_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00141_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00142_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00143_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00145_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00146_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00147_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\train\OBJ00151_PS3_K3_AIDATA0595.txt 업데이트 완료
# ./datasets/labels\train\OBJ00152_PS3_K3_AIDATA0595.txt 업데이트 완료
# ./datasets/labels\train\OBJ00153_PS3_K3_AIDATA0595.txt 업데이트 완료
# ./datasets/labels\train\OBJ00154_PS3_K3_AIDATA0595.txt 업데이트 완료
# ./datasets/labels\train\OBJ00155_PS3_K3_AIDATA0595.txt 업데이트 완료
# ./datasets/labels\train\OBJ00159_PS3_K3_AIDATA0596.txt 업데이트 완료
# ./datasets/labels\train\OBJ00164_PS3_K3_AIDATA0598.txt 업데이트 완료
# ./datasets/labels\train\OBJ00165_PS3_K3_AIDATA0598.txt 업데이트 완료
# ./datasets/labels\train\OBJ00167_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00168_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00169_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00170_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00172_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00174_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00175_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00177_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00179_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00180_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\train\OBJ00182_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00184_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00185_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00186_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00187_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00189_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00191_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\train\OBJ00195_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00196_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00197_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00200_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00201_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00204_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00206_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00210_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00211_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00212_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00213_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\train\OBJ00219_PS3_K3A_AIDATA0603.txt 업데이트 완료
# ./datasets/labels\train\OBJ00220_PS3_K3A_AIDATA0603.txt 업데이트 완료
# ./datasets/labels\train\OBJ00221_PS3_K3A_AIDATA0603.txt 업데이트 완료
# ./datasets/labels\train\OBJ00223_PS3_K3A_AIDATA0604.txt 업데이트 완료
# ./datasets/labels\train\OBJ00224_PS3_K3A_AIDATA0604.txt 업데이트 완료
# ./datasets/labels\train\OBJ00228_PS3_K3A_AIDATA0604.txt 업데이트 완료
# ./datasets/labels\train\OBJ00229_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00232_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00233_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00234_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00235_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00236_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00237_PS3_K3A_AIDATA0605.txt 업데이트 완료
# ./datasets/labels\train\OBJ00239_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00240_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00241_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00242_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00244_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00245_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00247_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00248_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00250_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00251_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00253_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00254_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00255_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00257_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00258_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\train\OBJ00264_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00265_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00266_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00267_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00269_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00271_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00272_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00274_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00275_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\train\OBJ00282_PS3_K3A_AIDATA0609.txt 업데이트 완료
# ./datasets/labels\train\OBJ00286_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00287_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00290_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00291_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00292_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00293_PS3_K3A_AIDATA0613.txt 업데이트 완료
# ./datasets/labels\train\OBJ00303_PS3_K3A_AIDATA0217.txt 업데이트 완료
# ./datasets/labels\train\OBJ00312_PS3_K3A_AIDATA0615.txt 업데이트 완료
# ./datasets/labels\train\OBJ00313_PS3_K3A_AIDATA0615.txt 업데이트 완료
# ./datasets/labels\train\OBJ00319_PS3_K3A_AIDATA0615.txt 업데이트 완료
# ./datasets/labels\train\OBJ00320_PS3_K3A_AIDATA0616.txt 업데이트 완료
# ./datasets/labels\train\OBJ00332_PS3_K3A_AIDATA0617.txt 업데이트 완료
# ./datasets/labels\train\OBJ00333_PS3_K3A_AIDATA0617.txt 업데이트 완료
# ./datasets/labels\train\OBJ00334_PS3_K3A_AIDATA0618.txt 업데이트 완료
# ./datasets/labels\train\OBJ00335_PS3_K3A_AIDATA0618.txt 업데이트 완료
# ./datasets/labels\train\OBJ00336_PS3_K3A_AIDATA0618.txt 업데이트 완료
# ./datasets/labels\train\OBJ00348_PS3_K3A_AIDATA0619.txt 업데이트 완료
# ./datasets/labels\train\OBJ00349_PS3_K3A_AIDATA0619.txt 업데이트 완료
# ./datasets/labels\train\OBJ00353_PS3_K3A_AIDATA0621.txt 업데이트 완료
# ./datasets/labels\train\OBJ00354_PS3_K3A_AIDATA0622.txt 업데이트 완료
# ./datasets/labels\train\OBJ00359_PS3_K3A_AIDATA0625.txt 업데이트 완료
# ./datasets/labels\train\OBJ01068_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01069_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01072_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01074_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01113_PS3_K3A_AIDATA0702.txt 업데이트 완료
# ./datasets/labels\train\OBJ01114_PS3_K3A_AIDATA0703.txt 업데이트 완료
# ./datasets/labels\train\OBJ01115_PS3_K3A_AIDATA0704.txt 업데이트 완료
# ./datasets/labels\train\OBJ01116_PS3_K3A_AIDATA0684.txt 업데이트 완료
# ./datasets/labels\train\OBJ01117_PS3_K3A_AIDATA0684.txt 업데이트 완료
# ./datasets/labels\train\OBJ01118_PS3_K3A_AIDATA0705.txt 업데이트 완료
# ./datasets/labels\train\OBJ01119_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01120_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01122_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01123_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01124_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01125_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01126_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01127_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01128_PS3_K3_AIDATA0708.txt 업데이트 완료
# ./datasets/labels\train\OBJ01130_PS3_K3_AIDATA0709.txt 업데이트 완료
# ./datasets/labels\train\OBJ01131_PS3_K3_AIDATA0687.txt 업데이트 완료
# ./datasets/labels\train\OBJ01132_PS3_K3_AIDATA0687.txt 업데이트 완료
# ./datasets/labels\train\OBJ01133_PS3_K3_AIDATA0687.txt 업데이트 완료
# ./datasets/labels\train\OBJ01134_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01135_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01136_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01138_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01139_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01140_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01142_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01143_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01144_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01145_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01146_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01147_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01149_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01150_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01151_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01152_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01155_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01157_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01158_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01159_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01160_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01162_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01164_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01165_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01167_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01168_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01170_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01171_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01172_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01173_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01174_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01175_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01176_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01177_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01178_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01180_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01181_PS3_K3A_AIDATA0710.txt 업데이트 완료
# ./datasets/labels\train\OBJ01182_PS3_K3A_AIDATA0710.txt 업데이트 완료
# ./datasets/labels\train\OBJ01183_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01184_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01185_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01186_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01187_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01189_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01190_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01191_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01192_PS3_K3A_AIDATA0674.txt 업데이트 완료
# ./datasets/labels\train\OBJ01193_PS3_K3A_AIDATA0674.txt 업데이트 완료
# ./datasets/labels\train\OBJ01194_PS3_K3_AIDATA0711.txt 업데이트 완료
# ./datasets/labels\train\OBJ01195_PS3_K3_AIDATA0711.txt 업데이트 완료
# ./datasets/labels\train\OBJ01196_PS3_K3_AIDATA0712.txt 업데이트 완료
# ./datasets/labels\train\OBJ01197_PS3_K3_AIDATA0712.txt 업데이트 완료
# ./datasets/labels\train\OBJ01198_PS3_K3_AIDATA0712.txt 업데이트 완료
# ./datasets/labels\train\OBJ01199_PS3_K3_AIDATA0712.txt 업데이트 완료
# ./datasets/labels\train\OBJ01204_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01205_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01206_PS3_K3A_AIDATA0107.txt 업데이트 완료
# ./datasets/labels\train\OBJ01207_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01208_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01209_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01210_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01211_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01212_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01213_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\train\OBJ01214_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01216_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01217_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01218_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01220_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01221_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01224_PS3_K3A_AIDATA0713.txt 업데이트 완료
# ./datasets/labels\train\OBJ01225_PS3_K3A_AIDATA0713.txt 업데이트 완료
# ./datasets/labels\train\OBJ01226_PS3_K3A_AIDATA0713.txt 업데이트 완료
# ./datasets/labels\train\OBJ01227_PS3_K3A_AIDATA0713.txt 업데이트 완료
# ./datasets/labels\train\OBJ01228_PS3_K3A_AIDATA0693.txt 업데이트 완료
# ./datasets/labels\train\OBJ01229_PS3_K3A_AIDATA0693.txt 업데이트 완료
# ./datasets/labels\train\OBJ01231_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01233_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01234_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01235_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01236_PS3_K3A_AIDATA0715.txt 업데이트 완료
# ./datasets/labels\train\OBJ01237_PS3_K3A_AIDATA0715.txt 업데이트 완료
# ./datasets/labels\train\OBJ01238_PS3_K3A_AIDATA0695.txt 업데이트 완료
# ./datasets/labels\train\OBJ01239_PS3_K3A_AIDATA0695.txt 업데이트 완료
# ./datasets/labels\train\OBJ01240_PS3_K3_AIDATA0697.txt 업데이트 완료
# ./datasets/labels\train\OBJ01241_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01242_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01244_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01245_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01246_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01247_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01249_PS3_K3A_AIDATA0680.txt 업데이트 완료
# ./datasets/labels\train\OBJ01251_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01252_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01253_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01254_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01255_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01257_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01258_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01259_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01260_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01261_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01263_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01264_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01265_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01267_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01268_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01269_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01270_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01272_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01273_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01274_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01275_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01277_PS3_K3A_AIDATA0638.txt 업데이트 완료
# ./datasets/labels\train\OBJ01278_PS3_K3A_AIDATA0638.txt 업데이트 완료
# ./datasets/labels\train\OBJ01279_PS3_K3A_AIDATA0638.txt 업데이트 완료
# ./datasets/labels\train\OBJ01280_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01283_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01284_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01285_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01286_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01287_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01288_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01289_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01290_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01291_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01313_PS3_K3A_AIDATA0731.txt 업데이트 완료
# ./datasets/labels\train\OBJ01314_PS3_K3A_AIDATA0673.txt 업데이트 완료
# ./datasets/labels\train\OBJ01328_PS3_K3A_AIDATA0744.txt 업데이트 완료
# ./datasets/labels\train\OBJ01338_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01340_PS3_K3_AIDATA0754.txt 업데이트 완료
# ./datasets/labels\train\OBJ01348_PS3_K3_AIDATA0677.txt 업데이트 완료
# ./datasets/labels\train\OBJ01354_PS3_K3_AIDATA0678.txt 업데이트 완료
# ./datasets/labels\train\OBJ01355_PS3_K3_AIDATA0678.txt 업데이트 완료
# ./datasets/labels\train\OBJ01356_PS3_K3A_AIDATA0118.txt 업데이트 완료
# ./datasets/labels\train\OBJ01393_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\train\OBJ01420_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01427_PS3_K3A_AIDATA0785.txt 업데이트 완료
# ./datasets/labels\train\OBJ01428_PS3_K3A_AIDATA0786.txt 업데이트 완료
# ./datasets/labels\train\OBJ01429_PS3_K3A_AIDATA0786.txt 업데이트 완료
# ./datasets/labels\train\OBJ01430_PS3_K3A_AIDATA0221.txt 업데이트 완료
# ./datasets/labels\train\OBJ01431_PS3_K3A_AIDATA0221.txt 업데이트 완료
# ./datasets/labels\train\OBJ01434_PS3_K3A_AIDATA0787.txt 업데이트 완료
# ./datasets/labels\train\OBJ01435_PS3_K3A_AIDATA0788.txt 업데이트 완료
# ./datasets/labels\train\OBJ01436_PS3_K3A_AIDATA0684.txt 업데이트 완료
# ./datasets/labels\train\OBJ01438_PS3_K3A_AIDATA0776.txt 업데이트 완료
# ./datasets/labels\train\OBJ01439_PS3_K3A_AIDATA0685.txt 업데이트 완료
# ./datasets/labels\train\OBJ01441_PS3_K3A_AIDATA0778.txt 업데이트 완료
# ./datasets/labels\train\OBJ01442_PS3_K3A_AIDATA0705.txt 업데이트 완료
# ./datasets/labels\train\OBJ01443_PS3_K3A_AIDATA0705.txt 업데이트 완료
# ./datasets/labels\train\OBJ01444_PS3_K3A_AIDATA0789.txt 업데이트 완료
# ./datasets/labels\train\OBJ01445_PS3_K3A_AIDATA0790.txt 업데이트 완료
# ./datasets/labels\train\OBJ01446_PS3_K3A_AIDATA0790.txt 업데이트 완료
# ./datasets/labels\train\OBJ01447_PS3_K3A_AIDATA0790.txt 업데이트 완료
# ./datasets/labels\train\OBJ01448_PS3_K3A_AIDATA0790.txt 업데이트 완료
# ./datasets/labels\train\OBJ01451_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01452_PS3_K3A_AIDATA0727.txt 업데이트 완료
# ./datasets/labels\train\OBJ01453_PS3_K3A_AIDATA0731.txt 업데이트 완료
# ./datasets/labels\train\OBJ01455_PS3_K3A_AIDATA0732.txt 업데이트 완료
# ./datasets/labels\train\OBJ01458_PS3_K3A_AIDATA0741.txt 업데이트 완료
# ./datasets/labels\train\OBJ01459_PS3_K3A_AIDATA0741.txt 업데이트 완료
# ./datasets/labels\train\OBJ01460_PS3_K3A_AIDATA0744.txt 업데이트 완료
# ./datasets/labels\train\OBJ01461_PS3_K3A_AIDATA0744.txt 업데이트 완료
# ./datasets/labels\train\OBJ01462_PS3_K3A_AIDATA0744.txt 업데이트 완료
# ./datasets/labels\train\OBJ01465_PS3_K3_AIDATA0687.txt 업데이트 완료
# ./datasets/labels\train\OBJ01467_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01468_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01471_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01472_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01473_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01474_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01476_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01477_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01478_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01481_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01482_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01483_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01484_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01485_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01486_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01487_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01488_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01489_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\train\OBJ01490_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01492_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01493_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01494_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01495_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01496_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01497_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01498_PS3_K3A_AIDATA0674.txt 업데이트 완료
# ./datasets/labels\train\OBJ01499_PS3_K3A_AIDATA0675.txt 업데이트 완료
# ./datasets/labels\train\OBJ01500_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\train\OBJ01501_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\train\OBJ01502_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\train\OBJ01504_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\train\OBJ01505_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01506_PS3_K3A_AIDATA0691.txt 업데이트 완료
# ./datasets/labels\train\OBJ01507_PS3_K3A_AIDATA0695.txt 업데이트 완료
# ./datasets/labels\train\OBJ01510_PS3_K3_AIDATA0677.txt 업데이트 완료
# ./datasets/labels\train\OBJ01513_PS3_K3A_AIDATA0791.txt 업데이트 완료
# ./datasets/labels\train\OBJ01514_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01517_PS3_K3A_AIDATA0717.txt 업데이트 완료
# ./datasets/labels\train\OBJ01518_PS3_K3A_AIDATA0717.txt 업데이트 완료
# ./datasets/labels\train\OBJ01519_PS3_K3A_AIDATA0717.txt 업데이트 완료
# ./datasets/labels\train\OBJ01520_PS3_K3A_AIDATA0680.txt 업데이트 완료
# ./datasets/labels\train\OBJ01521_PS3_K3A_AIDATA0680.txt 업데이트 완료
# ./datasets/labels\train\OBJ01522_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01523_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01524_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\train\OBJ01525_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01526_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01527_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01529_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01531_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01532_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01533_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01535_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01537_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01538_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\train\OBJ01540_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01541_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\train\OBJ01550_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01551_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01553_PS3_K3_AIDATA0709.txt 업데이트 완료
# ./datasets/labels\train\OBJ01555_PS3_K3_AIDATA0792.txt 업데이트 완료
# ./datasets/labels\train\OBJ01557_PS3_K3A_AIDATA0685.txt 업데이트 완료
# ./datasets/labels\train\OBJ01558_PS3_K3A_AIDATA0705.txt 업데이트 완료
# ./datasets/labels\train\OBJ01571_PS3_K3A_AIDATA0691.txt 업데이트 완료
# ./datasets/labels\train\OBJ01572_PS3_K3A_AIDATA0691.txt 업데이트 완료
# ./datasets/labels\train\OBJ01575_PS3_K3A_AIDATA0693.txt 업데이트 완료
# ./datasets/labels\train\OBJ01580_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01602_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\train\OBJ01605_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01609_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01612_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01615_PS3_K3A_AIDATA0631.txt 업데이트 완료
# ./datasets/labels\train\OBJ01616_PS3_K3A_AIDATA0692.txt 업데이트 완료
# ./datasets/labels\train\OBJ01617_PS3_K3A_AIDATA0717.txt 업데이트 완료
# ./datasets/labels\train\OBJ01624_PS3_K3_AIDATA0706.txt 업데이트 완료
# ./datasets/labels\train\OBJ01625_PS3_K3_AIDATA0707.txt 업데이트 완료
# ./datasets/labels\train\OBJ01626_PS3_K3A_AIDATA0514.txt 업데이트 완료
# ./datasets/labels\train\OBJ01627_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01628_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01629_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01630_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01631_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01632_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01634_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\train\OBJ01661_PS3_K3A_AIDATA0675.txt 업데이트 완료
# ./datasets/labels\train\OBJ01674_PS3_K3A_AIDATA0684.txt 업데이트 완료
# ./datasets/labels\train\OBJ01679_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\train\OBJ01683_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01690_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01691_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01692_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\train\OBJ01695_PS3_K3A_AIDATA0690.txt 업데이트 완료
# ./datasets/labels\train\OBJ03734_PS3_K3A_NIA0156.txt 업데이트 완료
# ./datasets/labels\val\OBJ00010_PS3_K3_AIDATA0585.txt 업데이트 완료
# ./datasets/labels\val\OBJ00096_PS3_K3A_AIDATA0589.txt 업데이트 완료
# ./datasets/labels\val\OBJ00114_PS3_K3A_AIDATA0590.txt 업데이트 완료
# ./datasets/labels\val\OBJ00120_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\val\OBJ00122_PS3_K3A_AIDATA0591.txt 업데이트 완료
# ./datasets/labels\val\OBJ00144_PS3_K3_AIDATA0594.txt 업데이트 완료
# ./datasets/labels\val\OBJ00158_PS3_K3_AIDATA0596.txt 업데이트 완료
# ./datasets/labels\val\OBJ00171_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\val\OBJ00178_PS3_K3_AIDATA0599.txt 업데이트 완료
# ./datasets/labels\val\OBJ00192_PS3_K3_AIDATA0600.txt 업데이트 완료
# ./datasets/labels\val\OBJ00199_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\val\OBJ00208_PS3_K3_AIDATA0601.txt 업데이트 완료
# ./datasets/labels\val\OBJ00243_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\val\OBJ00256_PS3_K3A_AIDATA0606.txt 업데이트 완료
# ./datasets/labels\val\OBJ00268_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\val\OBJ00270_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\val\OBJ00273_PS3_K3A_AIDATA0607.txt 업데이트 완료
# ./datasets/labels\val\OBJ00347_PS3_K3A_AIDATA0619.txt 업데이트 완료
# ./datasets/labels\val\OBJ01129_PS3_K3_AIDATA0708.txt 업데이트 완료
# ./datasets/labels\val\OBJ01154_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\val\OBJ01161_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\val\OBJ01163_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\val\OBJ01169_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\val\OBJ01179_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/labels\val\OBJ01203_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\val\OBJ01206_PS3_K3A_AIDATA0630.txt 업데이트 완료
# ./datasets/labels\val\OBJ01222_PS3_K3A_AIDATA0692.txt 업데이트 완료
# ./datasets/labels\val\OBJ01230_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\val\OBJ01232_PS3_K3A_AIDATA0714.txt 업데이트 완료
# ./datasets/labels\val\OBJ01243_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\val\OBJ01250_PS3_K3A_AIDATA0680.txt 업데이트 완료
# ./datasets/labels\val\OBJ01256_PS3_K3A_AIDATA0632.txt 업데이트 완료
# ./datasets/labels\val\OBJ01266_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\val\OBJ01271_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\val\OBJ01281_PS3_K3A_AIDATA0641.txt 업데이트 완료
# ./datasets/labels\val\OBJ01320_PS3_K3A_AIDATA0686.txt 업데이트 완료
# ./datasets/labels\val\OBJ01341_PS3_K3_AIDATA0755.txt 업데이트 완료
# ./datasets/labels\val\OBJ01433_PS3_K3A_AIDATA0221.txt 업데이트 완료
# ./datasets/labels\val\OBJ01437_PS3_K3A_AIDATA0684.txt 업데이트 완료
# ./datasets/labels\val\OBJ01456_PS3_K3A_AIDATA0740.txt 업데이트 완료
# ./datasets/labels\val\OBJ01463_PS3_K3A_AIDATA0744.txt 업데이트 완료
# ./datasets/labels\val\OBJ01464_PS3_K3_AIDATA0687.txt 업데이트 완료
# ./datasets/labels\val\OBJ01480_PS3_K3A_AIDATA0515.txt 업데이트 완료
# ./datasets/labels\val\OBJ01491_PS3_K3A_AIDATA0455.txt 업데이트 완료
# ./datasets/labels\val\OBJ01503_PS3_K3A_AIDATA0629.txt 업데이트 완료
# ./datasets/labels\val\OBJ01508_PS3_K3_AIDATA0754.txt 업데이트 완료
# ./datasets/labels\val\OBJ01509_PS3_K3_AIDATA0755.txt 업데이트 완료
# ./datasets/labels\val\OBJ01512_PS3_K3A_AIDATA0791.txt 업데이트 완료
# ./datasets/labels\val\OBJ01515_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\val\OBJ01516_PS3_K3A_AIDATA0716.txt 업데이트 완료
# ./datasets/labels\val\OBJ01528_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\val\OBJ01536_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\val\OBJ01539_PS3_K3A_AIDATA0634.txt 업데이트 완료
# ./datasets/labels\val\OBJ01565_PS3_K3A_AIDATA0688.txt 업데이트 완료
# ./datasets/labels\val\OBJ01682_PS3_K3A_AIDATA0450.txt 업데이트 완료
# ./datasets/images\train\OBJ00032_PS3_K3_AIDATA0585.png 이미지 복사 완료
# ./datasets/images\train\OBJ00036_PS3_K3_AIDATA0585.png 이미지 복사 완료
# ./datasets/images\train\OBJ00059_PS3_K3_AIDATA0587.png 이미지 복사 완료
# ./datasets/images\train\OBJ00068_PS3_K3_AIDATA0587.png 이미지 복사 완료
# ./datasets/images\train\OBJ00111_PS3_K3A_AIDATA0589.png 이미지 복사 완료
# ./datasets/images\train\OBJ00115_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00116_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00117_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00118_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00121_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00123_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00124_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00125_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00126_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\train\OBJ00134_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00137_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00138_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00139_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00140_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00141_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00142_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00143_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00145_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00146_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00147_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\train\OBJ00151_PS3_K3_AIDATA0595.png 이미지 복사 완료
# ./datasets/images\train\OBJ00152_PS3_K3_AIDATA0595.png 이미지 복사 완료
# ./datasets/images\train\OBJ00153_PS3_K3_AIDATA0595.png 이미지 복사 완료
# ./datasets/images\train\OBJ00154_PS3_K3_AIDATA0595.png 이미지 복사 완료
# ./datasets/images\train\OBJ00155_PS3_K3_AIDATA0595.png 이미지 복사 완료
# ./datasets/images\train\OBJ00159_PS3_K3_AIDATA0596.png 이미지 복사 완료
# ./datasets/images\train\OBJ00164_PS3_K3_AIDATA0598.png 이미지 복사 완료
# ./datasets/images\train\OBJ00165_PS3_K3_AIDATA0598.png 이미지 복사 완료
# ./datasets/images\train\OBJ00167_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00168_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00169_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00170_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00172_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00174_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00175_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00177_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00179_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00180_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\train\OBJ00182_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00184_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00185_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00186_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00187_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00189_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00191_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\train\OBJ00195_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00196_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00197_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00200_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00201_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00204_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00206_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00210_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00211_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00212_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00213_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\train\OBJ00219_PS3_K3A_AIDATA0603.png 이미지 복사 완료
# ./datasets/images\train\OBJ00220_PS3_K3A_AIDATA0603.png 이미지 복사 완료
# ./datasets/images\train\OBJ00221_PS3_K3A_AIDATA0603.png 이미지 복사 완료
# ./datasets/images\train\OBJ00223_PS3_K3A_AIDATA0604.png 이미지 복사 완료
# ./datasets/images\train\OBJ00224_PS3_K3A_AIDATA0604.png 이미지 복사 완료
# ./datasets/images\train\OBJ00228_PS3_K3A_AIDATA0604.png 이미지 복사 완료
# ./datasets/images\train\OBJ00229_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00232_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00233_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00234_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00235_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00236_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00237_PS3_K3A_AIDATA0605.png 이미지 복사 완료
# ./datasets/images\train\OBJ00239_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00240_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00241_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00242_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00244_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00245_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00247_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00248_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00250_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00251_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00253_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00254_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00255_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00257_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00258_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\train\OBJ00264_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00265_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00266_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00267_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00269_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00271_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00272_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00274_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00275_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\train\OBJ00282_PS3_K3A_AIDATA0609.png 이미지 복사 완료
# ./datasets/images\train\OBJ00286_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00287_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00290_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00291_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00292_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00293_PS3_K3A_AIDATA0613.png 이미지 복사 완료
# ./datasets/images\train\OBJ00303_PS3_K3A_AIDATA0217.png 이미지 복사 완료
# ./datasets/images\train\OBJ00312_PS3_K3A_AIDATA0615.png 이미지 복사 완료
# ./datasets/images\train\OBJ00313_PS3_K3A_AIDATA0615.png 이미지 복사 완료
# ./datasets/images\train\OBJ00319_PS3_K3A_AIDATA0615.png 이미지 복사 완료
# ./datasets/images\train\OBJ00320_PS3_K3A_AIDATA0616.png 이미지 복사 완료
# ./datasets/images\train\OBJ00332_PS3_K3A_AIDATA0617.png 이미지 복사 완료
# ./datasets/images\train\OBJ00333_PS3_K3A_AIDATA0617.png 이미지 복사 완료
# ./datasets/images\train\OBJ00334_PS3_K3A_AIDATA0618.png 이미지 복사 완료
# ./datasets/images\train\OBJ00335_PS3_K3A_AIDATA0618.png 이미지 복사 완료
# ./datasets/images\train\OBJ00336_PS3_K3A_AIDATA0618.png 이미지 복사 완료
# ./datasets/images\train\OBJ00348_PS3_K3A_AIDATA0619.png 이미지 복사 완료
# ./datasets/images\train\OBJ00349_PS3_K3A_AIDATA0619.png 이미지 복사 완료
# ./datasets/images\train\OBJ00353_PS3_K3A_AIDATA0621.png 이미지 복사 완료
# ./datasets/images\train\OBJ00354_PS3_K3A_AIDATA0622.png 이미지 복사 완료
# ./datasets/images\train\OBJ00359_PS3_K3A_AIDATA0625.png 이미지 복사 완료
# ./datasets/images\train\OBJ01068_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01069_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01072_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01074_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01113_PS3_K3A_AIDATA0702.png 이미지 복사 완료
# ./datasets/images\train\OBJ01114_PS3_K3A_AIDATA0703.png 이미지 복사 완료
# ./datasets/images\train\OBJ01115_PS3_K3A_AIDATA0704.png 이미지 복사 완료
# ./datasets/images\train\OBJ01116_PS3_K3A_AIDATA0684.png 이미지 복사 완료
# ./datasets/images\train\OBJ01117_PS3_K3A_AIDATA0684.png 이미지 복사 완료
# ./datasets/images\train\OBJ01118_PS3_K3A_AIDATA0705.png 이미지 복사 완료
# ./datasets/images\train\OBJ01119_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01120_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01122_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01123_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01124_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01125_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01126_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01127_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01128_PS3_K3_AIDATA0708.png 이미지 복사 완료
# ./datasets/images\train\OBJ01130_PS3_K3_AIDATA0709.png 이미지 복사 완료
# ./datasets/images\train\OBJ01131_PS3_K3_AIDATA0687.png 이미지 복사 완료
# ./datasets/images\train\OBJ01132_PS3_K3_AIDATA0687.png 이미지 복사 완료
# ./datasets/images\train\OBJ01133_PS3_K3_AIDATA0687.png 이미지 복사 완료
# ./datasets/images\train\OBJ01134_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01135_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01136_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01138_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01139_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01140_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01142_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01143_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01144_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01145_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01146_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01147_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01149_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01150_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01151_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01152_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01155_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01157_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01158_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01159_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01160_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01162_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01164_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01165_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01167_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01168_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01170_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01171_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01172_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01173_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01174_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01175_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01176_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01177_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01178_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01180_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01181_PS3_K3A_AIDATA0710.png 이미지 복사 완료
# ./datasets/images\train\OBJ01182_PS3_K3A_AIDATA0710.png 이미지 복사 완료
# ./datasets/images\train\OBJ01183_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01184_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01185_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01186_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01187_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01189_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01190_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01191_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01192_PS3_K3A_AIDATA0674.png 이미지 복사 완료
# ./datasets/images\train\OBJ01193_PS3_K3A_AIDATA0674.png 이미지 복사 완료
# ./datasets/images\train\OBJ01194_PS3_K3_AIDATA0711.png 이미지 복사 완료
# ./datasets/images\train\OBJ01195_PS3_K3_AIDATA0711.png 이미지 복사 완료
# ./datasets/images\train\OBJ01196_PS3_K3_AIDATA0712.png 이미지 복사 완료
# ./datasets/images\train\OBJ01197_PS3_K3_AIDATA0712.png 이미지 복사 완료
# ./datasets/images\train\OBJ01198_PS3_K3_AIDATA0712.png 이미지 복사 완료
# ./datasets/images\train\OBJ01199_PS3_K3_AIDATA0712.png 이미지 복사 완료
# ./datasets/images\train\OBJ01204_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01205_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01206_PS3_K3A_AIDATA0107.png 이미지 복사 완료
# ./datasets/images\train\OBJ01207_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01208_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01209_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01210_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01211_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01212_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01213_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\train\OBJ01214_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01216_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01217_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01218_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01220_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01221_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01224_PS3_K3A_AIDATA0713.png 이미지 복사 완료
# ./datasets/images\train\OBJ01225_PS3_K3A_AIDATA0713.png 이미지 복사 완료
# ./datasets/images\train\OBJ01226_PS3_K3A_AIDATA0713.png 이미지 복사 완료
# ./datasets/images\train\OBJ01227_PS3_K3A_AIDATA0713.png 이미지 복사 완료
# ./datasets/images\train\OBJ01228_PS3_K3A_AIDATA0693.png 이미지 복사 완료
# ./datasets/images\train\OBJ01229_PS3_K3A_AIDATA0693.png 이미지 복사 완료
# ./datasets/images\train\OBJ01231_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01233_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01234_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01235_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01236_PS3_K3A_AIDATA0715.png 이미지 복사 완료
# ./datasets/images\train\OBJ01237_PS3_K3A_AIDATA0715.png 이미지 복사 완료
# ./datasets/images\train\OBJ01238_PS3_K3A_AIDATA0695.png 이미지 복사 완료
# ./datasets/images\train\OBJ01239_PS3_K3A_AIDATA0695.png 이미지 복사 완료
# ./datasets/images\train\OBJ01240_PS3_K3_AIDATA0697.png 이미지 복사 완료
# ./datasets/images\train\OBJ01241_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01242_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01244_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01245_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01246_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01247_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01249_PS3_K3A_AIDATA0680.png 이미지 복사 완료
# ./datasets/images\train\OBJ01251_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01252_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01253_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01254_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01255_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01257_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01258_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01259_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01260_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01261_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01263_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01264_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01265_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01267_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01268_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01269_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01270_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01272_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01273_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01274_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01275_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01277_PS3_K3A_AIDATA0638.png 이미지 복사 완료
# ./datasets/images\train\OBJ01278_PS3_K3A_AIDATA0638.png 이미지 복사 완료
# ./datasets/images\train\OBJ01279_PS3_K3A_AIDATA0638.png 이미지 복사 완료
# ./datasets/images\train\OBJ01280_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01283_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01284_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01285_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01286_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01287_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01288_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01289_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01290_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01291_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01313_PS3_K3A_AIDATA0731.png 이미지 복사 완료
# ./datasets/images\train\OBJ01314_PS3_K3A_AIDATA0673.png 이미지 복사 완료
# ./datasets/images\train\OBJ01328_PS3_K3A_AIDATA0744.png 이미지 복사 완료
# ./datasets/images\train\OBJ01338_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01340_PS3_K3_AIDATA0754.png 이미지 복사 완료
# ./datasets/images\train\OBJ01348_PS3_K3_AIDATA0677.png 이미지 복사 완료
# ./datasets/images\train\OBJ01354_PS3_K3_AIDATA0678.png 이미지 복사 완료
# ./datasets/images\train\OBJ01355_PS3_K3_AIDATA0678.png 이미지 복사 완료
# ./datasets/images\train\OBJ01356_PS3_K3A_AIDATA0118.png 이미지 복사 완료
# ./datasets/images\train\OBJ01393_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\train\OBJ01420_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01427_PS3_K3A_AIDATA0785.png 이미지 복사 완료
# ./datasets/images\train\OBJ01428_PS3_K3A_AIDATA0786.png 이미지 복사 완료
# ./datasets/images\train\OBJ01429_PS3_K3A_AIDATA0786.png 이미지 복사 완료
# ./datasets/images\train\OBJ01430_PS3_K3A_AIDATA0221.png 이미지 복사 완료
# ./datasets/images\train\OBJ01431_PS3_K3A_AIDATA0221.png 이미지 복사 완료
# ./datasets/images\train\OBJ01434_PS3_K3A_AIDATA0787.png 이미지 복사 완료
# ./datasets/images\train\OBJ01435_PS3_K3A_AIDATA0788.png 이미지 복사 완료
# ./datasets/images\train\OBJ01436_PS3_K3A_AIDATA0684.png 이미지 복사 완료
# ./datasets/images\train\OBJ01438_PS3_K3A_AIDATA0776.png 이미지 복사 완료
# ./datasets/images\train\OBJ01439_PS3_K3A_AIDATA0685.png 이미지 복사 완료
# ./datasets/images\train\OBJ01441_PS3_K3A_AIDATA0778.png 이미지 복사 완료
# ./datasets/images\train\OBJ01442_PS3_K3A_AIDATA0705.png 이미지 복사 완료
# ./datasets/images\train\OBJ01443_PS3_K3A_AIDATA0705.png 이미지 복사 완료
# ./datasets/images\train\OBJ01444_PS3_K3A_AIDATA0789.png 이미지 복사 완료
# ./datasets/images\train\OBJ01445_PS3_K3A_AIDATA0790.png 이미지 복사 완료
# ./datasets/images\train\OBJ01446_PS3_K3A_AIDATA0790.png 이미지 복사 완료
# ./datasets/images\train\OBJ01447_PS3_K3A_AIDATA0790.png 이미지 복사 완료
# ./datasets/images\train\OBJ01448_PS3_K3A_AIDATA0790.png 이미지 복사 완료
# ./datasets/images\train\OBJ01451_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01452_PS3_K3A_AIDATA0727.png 이미지 복사 완료
# ./datasets/images\train\OBJ01453_PS3_K3A_AIDATA0731.png 이미지 복사 완료
# ./datasets/images\train\OBJ01455_PS3_K3A_AIDATA0732.png 이미지 복사 완료
# ./datasets/images\train\OBJ01458_PS3_K3A_AIDATA0741.png 이미지 복사 완료
# ./datasets/images\train\OBJ01459_PS3_K3A_AIDATA0741.png 이미지 복사 완료
# ./datasets/images\train\OBJ01460_PS3_K3A_AIDATA0744.png 이미지 복사 완료
# ./datasets/images\train\OBJ01461_PS3_K3A_AIDATA0744.png 이미지 복사 완료
# ./datasets/images\train\OBJ01462_PS3_K3A_AIDATA0744.png 이미지 복사 완료
# ./datasets/images\train\OBJ01465_PS3_K3_AIDATA0687.png 이미지 복사 완료
# ./datasets/images\train\OBJ01467_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01468_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01471_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01472_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01473_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01474_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01476_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01477_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01478_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01481_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01482_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01483_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01484_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01485_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01486_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01487_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01488_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01489_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\train\OBJ01490_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01492_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01493_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01494_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01495_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01496_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01497_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01498_PS3_K3A_AIDATA0674.png 이미지 복사 완료
# ./datasets/images\train\OBJ01499_PS3_K3A_AIDATA0675.png 이미지 복사 완료
# ./datasets/images\train\OBJ01500_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\train\OBJ01501_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\train\OBJ01502_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\train\OBJ01504_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\train\OBJ01505_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01506_PS3_K3A_AIDATA0691.png 이미지 복사 완료
# ./datasets/images\train\OBJ01507_PS3_K3A_AIDATA0695.png 이미지 복사 완료
# ./datasets/images\train\OBJ01510_PS3_K3_AIDATA0677.png 이미지 복사 완료
# ./datasets/images\train\OBJ01513_PS3_K3A_AIDATA0791.png 이미지 복사 완료
# ./datasets/images\train\OBJ01514_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01517_PS3_K3A_AIDATA0717.png 이미지 복사 완료
# ./datasets/images\train\OBJ01518_PS3_K3A_AIDATA0717.png 이미지 복사 완료
# ./datasets/images\train\OBJ01519_PS3_K3A_AIDATA0717.png 이미지 복사 완료
# ./datasets/images\train\OBJ01520_PS3_K3A_AIDATA0680.png 이미지 복사 완료
# ./datasets/images\train\OBJ01521_PS3_K3A_AIDATA0680.png 이미지 복사 완료
# ./datasets/images\train\OBJ01522_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01523_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01524_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\train\OBJ01525_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01526_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01527_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01529_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01531_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01532_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01533_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01535_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01537_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01538_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\train\OBJ01540_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01541_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\train\OBJ01550_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01551_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01553_PS3_K3_AIDATA0709.png 이미지 복사 완료
# ./datasets/images\train\OBJ01555_PS3_K3_AIDATA0792.png 이미지 복사 완료
# ./datasets/images\train\OBJ01557_PS3_K3A_AIDATA0685.png 이미지 복사 완료
# ./datasets/images\train\OBJ01558_PS3_K3A_AIDATA0705.png 이미지 복사 완료
# ./datasets/images\train\OBJ01571_PS3_K3A_AIDATA0691.png 이미지 복사 완료
# ./datasets/images\train\OBJ01572_PS3_K3A_AIDATA0691.png 이미지 복사 완료
# ./datasets/images\train\OBJ01575_PS3_K3A_AIDATA0693.png 이미지 복사 완료
# ./datasets/images\train\OBJ01580_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01602_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\train\OBJ01605_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01609_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01612_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01615_PS3_K3A_AIDATA0631.png 이미지 복사 완료
# ./datasets/images\train\OBJ01616_PS3_K3A_AIDATA0692.png 이미지 복사 완료
# ./datasets/images\train\OBJ01617_PS3_K3A_AIDATA0717.png 이미지 복사 완료
# ./datasets/images\train\OBJ01624_PS3_K3_AIDATA0706.png 이미지 복사 완료
# ./datasets/images\train\OBJ01625_PS3_K3_AIDATA0707.png 이미지 복사 완료
# ./datasets/images\train\OBJ01626_PS3_K3A_AIDATA0514.png 이미지 복사 완료
# ./datasets/images\train\OBJ01627_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01628_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01629_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01630_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01631_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01632_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01634_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\train\OBJ01661_PS3_K3A_AIDATA0675.png 이미지 복사 완료
# ./datasets/images\train\OBJ01674_PS3_K3A_AIDATA0684.png 이미지 복사 완료
# ./datasets/images\train\OBJ01679_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\train\OBJ01683_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01690_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01691_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01692_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\train\OBJ01695_PS3_K3A_AIDATA0690.png 이미지 복사 완료
# ./datasets/images\train\OBJ03734_PS3_K3A_NIA0156.png 이미지 복사 완료
# ./datasets/images\val\OBJ00010_PS3_K3_AIDATA0585.png 이미지 복사 완료
# ./datasets/images\val\OBJ00096_PS3_K3A_AIDATA0589.png 이미지 복사 완료
# ./datasets/images\val\OBJ00114_PS3_K3A_AIDATA0590.png 이미지 복사 완료
# ./datasets/images\val\OBJ00120_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\val\OBJ00122_PS3_K3A_AIDATA0591.png 이미지 복사 완료
# ./datasets/images\val\OBJ00144_PS3_K3_AIDATA0594.png 이미지 복사 완료
# ./datasets/images\val\OBJ00158_PS3_K3_AIDATA0596.png 이미지 복사 완료
# ./datasets/images\val\OBJ00171_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\val\OBJ00178_PS3_K3_AIDATA0599.png 이미지 복사 완료
# ./datasets/images\val\OBJ00192_PS3_K3_AIDATA0600.png 이미지 복사 완료
# ./datasets/images\val\OBJ00199_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\val\OBJ00208_PS3_K3_AIDATA0601.png 이미지 복사 완료
# ./datasets/images\val\OBJ00243_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\val\OBJ00256_PS3_K3A_AIDATA0606.png 이미지 복사 완료
# ./datasets/images\val\OBJ00268_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\val\OBJ00270_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\val\OBJ00273_PS3_K3A_AIDATA0607.png 이미지 복사 완료
# ./datasets/images\val\OBJ00347_PS3_K3A_AIDATA0619.png 이미지 복사 완료
# ./datasets/images\val\OBJ01129_PS3_K3_AIDATA0708.png 이미지 복사 완료
# ./datasets/images\val\OBJ01154_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\val\OBJ01161_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\val\OBJ01163_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\val\OBJ01169_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\val\OBJ01179_PS3_K3A_AIDATA0450.png 이미지 복사 완료
# ./datasets/images\val\OBJ01203_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\val\OBJ01206_PS3_K3A_AIDATA0630.png 이미지 복사 완료
# ./datasets/images\val\OBJ01222_PS3_K3A_AIDATA0692.png 이미지 복사 완료
# ./datasets/images\val\OBJ01230_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\val\OBJ01232_PS3_K3A_AIDATA0714.png 이미지 복사 완료
# ./datasets/images\val\OBJ01243_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\val\OBJ01250_PS3_K3A_AIDATA0680.png 이미지 복사 완료
# ./datasets/images\val\OBJ01256_PS3_K3A_AIDATA0632.png 이미지 복사 완료
# ./datasets/images\val\OBJ01266_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\val\OBJ01271_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\val\OBJ01281_PS3_K3A_AIDATA0641.png 이미지 복사 완료
# ./datasets/images\val\OBJ01320_PS3_K3A_AIDATA0686.png 이미지 복사 완료
# ./datasets/images\val\OBJ01341_PS3_K3_AIDATA0755.png 이미지 복사 완료
# ./datasets/images\val\OBJ01433_PS3_K3A_AIDATA0221.png 이미지 복사 완료
# ./datasets/images\val\OBJ01437_PS3_K3A_AIDATA0684.png 이미지 복사 완료
# ./datasets/images\val\OBJ01456_PS3_K3A_AIDATA0740.png 이미지 복사 완료
# ./datasets/images\val\OBJ01463_PS3_K3A_AIDATA0744.png 이미지 복사 완료
# ./datasets/images\val\OBJ01464_PS3_K3_AIDATA0687.png 이미지 복사 완료
# ./datasets/images\val\OBJ01480_PS3_K3A_AIDATA0515.png 이미지 복사 완료
# ./datasets/images\val\OBJ01491_PS3_K3A_AIDATA0455.png 이미지 복사 완료
# ./datasets/images\val\OBJ01503_PS3_K3A_AIDATA0629.png 이미지 복사 완료
# ./datasets/images\val\OBJ01508_PS3_K3_AIDATA0754.png 이미지 복사 완료
# ./datasets/images\val\OBJ01509_PS3_K3_AIDATA0755.png 이미지 복사 완료
# ./datasets/images\val\OBJ01512_PS3_K3A_AIDATA0791.png 이미지 복사 완료
# ./datasets/images\val\OBJ01515_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\val\OBJ01516_PS3_K3A_AIDATA0716.png 이미지 복사 완료
# ./datasets/images\val\OBJ01528_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\val\OBJ01536_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\val\OBJ01539_PS3_K3A_AIDATA0634.png 이미지 복사 완료
# ./datasets/images\val\OBJ01565_PS3_K3A_AIDATA0688.png 이미지 복사 완료
# ./datasets/images\val\OBJ01682_PS3_K3A_AIDATA0450.png 이미지 복사 완료
