# %%
import os
import json
from tqdm import tqdm

def convert_imcoords_to_bbox(imcoords):
    # imcoords는 문자열 형태의 좌표를 파싱하여 리스트로 변환
    coords = list(map(float, imcoords.split(',')))
    x_values = coords[0::2]  # 짝수 인덱스는 x 좌표
    y_values = coords[1::2]  # 홀수 인덱스는 y 좌표
    
    # 좌표로부터 bbox의 중심 좌표(cx, cy), 너비(width), 높이(height) 계산
    x_min = min(x_values)
    x_max = max(x_values)
    y_min = min(y_values)
    y_max = max(y_values)
    
    cx = (x_min + x_max) / 2
    cy = (y_min + y_max) / 2
    width = x_max - x_min
    height = y_max - y_min
    
    return cx, cy, width, height

def filter_and_modify_json(directory, output_directory):
    # 지정된 디렉토리 내 모든 JSON 파일 확인
    for filename in tqdm(os.listdir(directory), desc="Processing files", unit="file"):
        if filename.endswith(".json"):
            input_file_path = os.path.join(directory, filename).replace('\\', '/')
            
            with open(input_file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
            
            # 새로운 피처 저장 리스트
            filtered_features = []

            # 'features' 필드가 있는지 확인하고 반복
            if 'features' in data:
                for feature in data['features']:
                    if 'properties' in feature:
                        type_name = feature['properties'].get('type_name')
                        
                        # 'type_name'이 'ship(S)' 또는 'ship(L)'인 경우만 처리
                        if type_name in ['ship(S)', 'ship(L)']:
                            imcoords = feature['properties'].get('object_imcoords')
                            if imcoords:
                                # 좌표 변환 후 새로운 값 추가
                                cx, cy, width, height = convert_imcoords_to_bbox(imcoords)
                                feature['properties']['cx'] = cx
                                feature['properties']['cy'] = cy
                                feature['properties']['width'] = width
                                feature['properties']['height'] = height
                                
                                # 기존 데이터와 함께 새로운 properties로 업데이트
                                filtered_features.append(feature)

            # 새로운 JSON 구조 생성
            if filtered_features:
                new_data = {
                    "type": "FeatureCollection",
                    "features": filtered_features
                }

                # 출력 경로 설정 (출력 폴더에 저장)
                output_file_path = os.path.join(output_directory, filename).replace('\\', '/')
                with open(output_file_path, 'w', encoding='utf-8') as outfile:
                    json.dump(new_data, outfile, ensure_ascii=False, indent=4)
import os
import json

def check_for_other_classes(directory):
    other_classes_found = False
    other_classes = set()

    # 지정된 디렉토리 내 모든 JSON 파일 확인
    for filename in os.listdir(directory):
        if filename.endswith(".json"):
            file_path = os.path.join(directory, filename).replace('\\', '/')
            
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
            
            # 'features' 필드가 있는지 확인하고 반복
            if 'features' in data:
                for feature in data['features']:
                    if 'properties' in feature:
                        type_name = feature['properties'].get('type_name')
                        
                        # 'ship(S)' 또는 'ship(L)' 외의 다른 클래스가 있는지 확인
                        if type_name not in ['ship(S)', 'ship(L)']:
                            other_classes_found = True
                            other_classes.add(type_name)

    # 결과 출력
    if other_classes_found:
        print("다른 클래스가 발견되었습니다:", other_classes)
    else:
        print("모든 JSON 파일이 'ship(S)' 또는 'ship(L)'만 포함하고 있습니다.")

# %%
# 사용 예시
input_directory = './train/train_objects_labels'  # 입력 JSON 파일들이 있는 폴더
output_directory = './datasets/labels/train'  # 필터링 후 JSON 파일을 저장할 폴더

# 출력 폴더가 없으면 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 필터링 및 변환 실행
filter_and_modify_json(input_directory, output_directory)
check_for_other_classes(output_directory)
# Out:
# Processing files: 100%|██████████| 1747/1747 [00:08<00:00, 218.30file/s]
# 모든 JSON 파일이 'ship(S)' 또는 'ship(L)'만 포함하고 있습니다.

# %%
# 사용 예시
input_directory = './valid/vaildate_objects_labels'  # 입력 JSON 파일들이 있는 폴더
output_directory = './datasets/labels/val'  # 필터링 후 JSON 파일을 저장할 폴더

# 출력 폴더가 없으면 생성
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# 필터링 및 변환 실행
filter_and_modify_json(input_directory, output_directory)
check_for_other_classes(output_directory)
# Out:
# Processing files: 100%|██████████| 219/219 [00:00<00:00, 254.46file/s]
# 모든 JSON 파일이 'ship(S)' 또는 'ship(L)'만 포함하고 있습니다.

# %%
train_list = os.listdir('./datasets/labels/train')
train_list.sort()
train_list
# Out:
# ['OBJ00022_PS3_K3_NIA0078.json',
#  'OBJ00022_PS3_K3_NIA0078.txt',
#  'OBJ00028_PS3_K3_NIA0078.json',
#  'OBJ00028_PS3_K3_NIA0078.txt',
#  'OBJ00258_PS3_K3_NIA0081.json',
#  'OBJ00258_PS3_K3_NIA0081.txt',
#  'OBJ00261_PS3_K3_NIA0081.json',
#  'OBJ00261_PS3_K3_NIA0081.txt',
#  'OBJ00607_PS3_K3_NIA0086.json',
#  'OBJ00607_PS3_K3_NIA0086.txt',
#  'OBJ01399_PS3_K3_NIA0093.json',
#  'OBJ01399_PS3_K3_NIA0093.txt',
#  'OBJ01400_PS3_K3_NIA0093.json',
#  'OBJ01400_PS3_K3_NIA0093.txt',
#  'OBJ01505_PS3_K3_NIA0095.json',
#  'OBJ01505_PS3_K3_NIA0095.txt',
#  'OBJ01589_PS3_K3_NIA0097.json',
#  'OBJ01589_PS3_K3_NIA0097.txt',
#  'OBJ01654_PS3_K3_NIA0101.json',
#  'OBJ01654_PS3_K3_NIA0101.txt',
#  'OBJ01675_PS3_K3_NIA0102.json',
#  'OBJ01675_PS3_K3_NIA0102.txt',
#  'OBJ01691_PS3_K3_NIA0102.json',
#  'OBJ01691_PS3_K3_NIA0102.txt',
#  'OBJ01696_PS3_K3_NIA0102.json',
#  'OBJ01696_PS3_K3_NIA0102.txt',
#  'OBJ01701_PS3_K3_NIA0102.json',
#  'OBJ01701_PS3_K3_NIA0102.txt',
#  'OBJ01735_PS3_K3_NIA0104.json',
#  'OBJ01735_PS3_K3_NIA0104.txt',
#  'OBJ01937_PS3_K3_NIA0110.json',
#  'OBJ01937_PS3_K3_NIA0110.txt',
#  'OBJ02050_PS3_K3_NIA0112.json',
#  'OBJ02050_PS3_K3_NIA0112.txt',
#  'OBJ02293_PS3_K3_NIA0118.json',
#  'OBJ02293_PS3_K3_NIA0118.txt',
#  'OBJ02297_PS3_K3_NIA0118.json',
#  'OBJ02297_PS3_K3_NIA0118.txt',
#  'OBJ02307_PS3_K3_NIA0118.json',
#  'OBJ02307_PS3_K3_NIA0118.txt',
#  'OBJ02311_PS3_K3_NIA0118.json',
#  'OBJ02311_PS3_K3_NIA0118.txt',
#  'OBJ02314_PS3_K3_NIA0118.json',
#  'OBJ02314_PS3_K3_NIA0118.txt',
#  'OBJ02400_PS3_K3_NIA0121.json',
#  'OBJ02400_PS3_K3_NIA0121.txt',
#  'OBJ02409_PS3_K3_NIA0121.json',
#  'OBJ02409_PS3_K3_NIA0121.txt',
#  'OBJ02417_PS3_K3_NIA0121.json',
#  'OBJ02417_PS3_K3_NIA0121.txt',
#  'OBJ02634_PS3_K3_NIA0126.json',
#  'OBJ02634_PS3_K3_NIA0126.txt',
#  'OBJ02635_PS3_K3_NIA0126.json',
#  'OBJ02635_PS3_K3_NIA0126.txt',
#  'OBJ02721_PS3_K3_NIA0126.json',
#  'OBJ02721_PS3_K3_NIA0126.txt',
#  'OBJ02723_PS3_K3_NIA0126.json',
#  'OBJ02723_PS3_K3_NIA0126.txt',
#  'OBJ02797_PS3_K3_NIA0126.json',
#  'OBJ02797_PS3_K3_NIA0126.txt',
#  'OBJ03271_PS3_K3_NIA0132.json',
#  'OBJ03271_PS3_K3_NIA0132.txt',
#  'OBJ03336_PS3_K3A_NIA0137.json',
#  'OBJ03336_PS3_K3A_NIA0137.txt',
#  'OBJ03399_PS3_K3A_NIA0138.json',
#  'OBJ03399_PS3_K3A_NIA0138.txt',
#  'OBJ03401_PS3_K3A_NIA0138.json',
#  'OBJ03401_PS3_K3A_NIA0138.txt',
#  'OBJ03403_PS3_K3A_NIA0138.json',
#  'OBJ03403_PS3_K3A_NIA0138.txt',
#  'OBJ03404_PS3_K3A_NIA0138.json',
#  'OBJ03404_PS3_K3A_NIA0138.txt',
#  'OBJ03405_PS3_K3A_NIA0138.json',
#  'OBJ03405_PS3_K3A_NIA0138.txt',
#  'OBJ03411_PS3_K3A_NIA0138.json',
#  'OBJ03411_PS3_K3A_NIA0138.txt',
#  'OBJ03413_PS3_K3A_NIA0138.json',
#  'OBJ03413_PS3_K3A_NIA0138.txt',
#  'OBJ03415_PS3_K3A_NIA0138.json',
#  'OBJ03415_PS3_K3A_NIA0138.txt',
#  'OBJ03424_PS3_K3A_NIA0139.json',
#  'OBJ03424_PS3_K3A_NIA0139.txt',
#  'OBJ03425_PS3_K3A_NIA0139.json',
#  'OBJ03425_PS3_K3A_NIA0139.txt',
#  'OBJ03426_PS3_K3A_NIA0139.json',
#  'OBJ03426_PS3_K3A_NIA0139.txt',
#  'OBJ03429_PS3_K3A_NIA0139.json',
#  'OBJ03429_PS3_K3A_NIA0139.txt',
#  'OBJ03435_PS3_K3A_NIA0139.json',
#  'OBJ03435_PS3_K3A_NIA0139.txt',
#  'OBJ03451_PS3_K3A_NIA0140.json',
#  'OBJ03451_PS3_K3A_NIA0140.txt',
#  'OBJ03453_PS3_K3A_NIA0140.json',
#  'OBJ03453_PS3_K3A_NIA0140.txt',
#  'OBJ03466_PS3_K3A_NIA0140.json',
#  'OBJ03466_PS3_K3A_NIA0140.txt',
#  'OBJ03468_PS3_K3A_NIA0141.json',
#  'OBJ03468_PS3_K3A_NIA0141.txt',
#  'OBJ03504_PS3_K3A_NIA0145.json',
#  'OBJ03504_PS3_K3A_NIA0145.txt',
#  'OBJ03509_PS3_K3A_NIA0145.json',
#  'OBJ03509_PS3_K3A_NIA0145.txt',
#  'OBJ03510_PS3_K3A_NIA0145.json',
#  'OBJ03510_PS3_K3A_NIA0145.txt',
#  'OBJ03514_PS3_K3A_NIA0146.json',
#  'OBJ03514_PS3_K3A_NIA0146.txt',
#  'OBJ03528_PS3_K3A_NIA0147.json',
#  'OBJ03528_PS3_K3A_NIA0147.txt',
#  'OBJ03538_PS3_K3A_NIA0148.json',
#  'OBJ03538_PS3_K3A_NIA0148.txt',
#  'OBJ03543_PS3_K3A_NIA0148.json',
#  'OBJ03543_PS3_K3A_NIA0148.txt',
#  'OBJ03697_PS3_K3A_NIA0155.json',
#  'OBJ03697_PS3_K3A_NIA0155.txt',
#  'OBJ03701_PS3_K3A_NIA0155.json',
#  'OBJ03701_PS3_K3A_NIA0155.txt',
#  'OBJ03702_PS3_K3A_NIA0155.json',
#  'OBJ03702_PS3_K3A_NIA0155.txt',
#  'OBJ03704_PS3_K3A_NIA0155.json',
#  'OBJ03704_PS3_K3A_NIA0155.txt',
#  'OBJ03708_PS3_K3A_NIA0156.json',
#  'OBJ03708_PS3_K3A_NIA0156.txt',
#  'OBJ03711_PS3_K3A_NIA0156.json',
#  'OBJ03711_PS3_K3A_NIA0156.txt',
#  'OBJ03713_PS3_K3A_NIA0156.json',
#  'OBJ03713_PS3_K3A_NIA0156.txt',
#  'OBJ03714_PS3_K3A_NIA0156.json',
#  'OBJ03714_PS3_K3A_NIA0156.txt',
#  'OBJ03720_PS3_K3A_NIA0156.json',
#  'OBJ03720_PS3_K3A_NIA0156.txt',
#  'OBJ03723_PS3_K3A_NIA0156.json',
#  'OBJ03723_PS3_K3A_NIA0156.txt',
#  'OBJ03724_PS3_K3A_NIA0156.json',
#  'OBJ03724_PS3_K3A_NIA0156.txt',
#  'OBJ03726_PS3_K3A_NIA0156.json',
#  'OBJ03726_PS3_K3A_NIA0156.txt',
#  'OBJ03727_PS3_K3A_NIA0156.json',
#  'OBJ03727_PS3_K3A_NIA0156.txt',
#  'OBJ03728_PS3_K3A_NIA0156.json',
#  'OBJ03728_PS3_K3A_NIA0156.txt',
#  'OBJ03730_PS3_K3A_NIA0156.json',
#  'OBJ03730_PS3_K3A_NIA0156.txt',
#  'OBJ03732_PS3_K3A_NIA0156.json',
#  'OBJ03732_PS3_K3A_NIA0156.txt',
#  'OBJ03733_PS3_K3A_NIA0156.json',
#  'OBJ03733_PS3_K3A_NIA0156.txt',
#  'OBJ03734_PS3_K3A_NIA0156.json',
#  'OBJ03734_PS3_K3A_NIA0156.txt',
#  'OBJ03736_PS3_K3A_NIA0156.json',
#  'OBJ03736_PS3_K3A_NIA0156.txt',
#  'OBJ03737_PS3_K3A_NIA0156.json',
#  'OBJ03737_PS3_K3A_NIA0156.txt',
#  'OBJ03738_PS3_K3A_NIA0156.json',
#  'OBJ03738_PS3_K3A_NIA0156.txt',
#  'OBJ03739_PS3_K3A_NIA0156.json',
#  'OBJ03739_PS3_K3A_NIA0156.txt',
#  'OBJ03743_PS3_K3A_NIA0156.json',
#  'OBJ03743_PS3_K3A_NIA0156.txt',
#  'OBJ03746_PS3_K3A_NIA0156.json',
#  'OBJ03746_PS3_K3A_NIA0156.txt',
#  'OBJ03754_PS3_K3A_NIA0157.json',
#  'OBJ03754_PS3_K3A_NIA0157.txt',
#  'OBJ03772_PS3_K3A_NIA0157.json',
#  'OBJ03772_PS3_K3A_NIA0157.txt',
#  'OBJ03774_PS3_K3A_NIA0157.json',
#  'OBJ03774_PS3_K3A_NIA0157.txt',
#  'OBJ03776_PS3_K3A_NIA0158.json',
#  'OBJ03776_PS3_K3A_NIA0158.txt',
#  'OBJ03784_PS3_K3A_NIA0158.json',
#  'OBJ03784_PS3_K3A_NIA0158.txt',
#  'OBJ03785_PS3_K3A_NIA0158.json',
#  'OBJ03785_PS3_K3A_NIA0158.txt',
#  'OBJ03789_PS3_K3A_NIA0158.json',
#  'OBJ03789_PS3_K3A_NIA0158.txt',
#  'OBJ03797_PS3_K3A_NIA0159.json',
#  'OBJ03797_PS3_K3A_NIA0159.txt',
#  'OBJ03814_PS3_K3A_NIA0159.json',
#  'OBJ03814_PS3_K3A_NIA0159.txt',
#  'OBJ03849_PS3_K3A_NIA0162.json',
#  'OBJ03849_PS3_K3A_NIA0162.txt',
#  'OBJ03851_PS3_K3A_NIA0162.json',
#  'OBJ03851_PS3_K3A_NIA0162.txt',
#  'OBJ03854_PS3_K3A_NIA0162.json',
#  'OBJ03854_PS3_K3A_NIA0162.txt',
#  'OBJ03857_PS3_K3A_NIA0162.json',
#  'OBJ03857_PS3_K3A_NIA0162.txt',
#  'OBJ03859_PS3_K3A_NIA0162.json',
#  'OBJ03859_PS3_K3A_NIA0162.txt',
#  'OBJ03861_PS3_K3A_NIA0162.json',
#  'OBJ03861_PS3_K3A_NIA0162.txt',
#  'OBJ03862_PS3_K3A_NIA0162.json',
#  'OBJ03862_PS3_K3A_NIA0162.txt',
#  'OBJ03863_PS3_K3A_NIA0162.json',
#  'OBJ03863_PS3_K3A_NIA0162.txt',
#  'OBJ03864_PS3_K3A_NIA0162.json',
#  'OBJ03864_PS3_K3A_NIA0162.txt',
#  'OBJ03865_PS3_K3A_NIA0162.json',
#  'OBJ03865_PS3_K3A_NIA0162.txt',
#  'OBJ03905_PS3_K3A_NIA0165.json',
#  'OBJ03905_PS3_K3A_NIA0165.txt',
#  'OBJ03915_PS3_K3A_NIA0165.json',
#  'OBJ03915_PS3_K3A_NIA0165.txt',
#  'OBJ03919_PS3_K3A_NIA0165.json',
#  'OBJ03919_PS3_K3A_NIA0165.txt',
#  'OBJ03925_PS3_K3A_NIA0166.json',
#  'OBJ03925_PS3_K3A_NIA0166.txt',
#  'OBJ03927_PS3_K3A_NIA0166.json',
#  'OBJ03927_PS3_K3A_NIA0166.txt',
#  'OBJ03928_PS3_K3A_NIA0166.json',
#  'OBJ03928_PS3_K3A_NIA0166.txt',
#  'OBJ03930_PS3_K3A_NIA0166.json',
#  'OBJ03930_PS3_K3A_NIA0166.txt',
#  'OBJ03932_PS3_K3A_NIA0166.json',
#  'OBJ03932_PS3_K3A_NIA0166.txt',
#  'OBJ03941_PS3_K3A_NIA0166.json',
#  'OBJ03941_PS3_K3A_NIA0166.txt',
#  'OBJ03947_PS3_K3A_NIA0166.json',
#  'OBJ03947_PS3_K3A_NIA0166.txt',
#  'OBJ03948_PS3_K3A_NIA0166.json',
#  'OBJ03948_PS3_K3A_NIA0166.txt',
#  'OBJ03949_PS3_K3A_NIA0166.json',
#  'OBJ03949_PS3_K3A_NIA0166.txt',
#  'OBJ03961_PS3_K3A_NIA0166.json',
#  'OBJ03961_PS3_K3A_NIA0166.txt',
#  'OBJ03963_PS3_K3A_NIA0166.json',
#  'OBJ03963_PS3_K3A_NIA0166.txt',
#  'OBJ03964_PS3_K3A_NIA0166.json',
#  'OBJ03964_PS3_K3A_NIA0166.txt',
#  'OBJ03965_PS3_K3A_NIA0166.json',
#  'OBJ03965_PS3_K3A_NIA0166.txt',
#  'OBJ03967_PS3_K3A_NIA0166.json',
#  'OBJ03967_PS3_K3A_NIA0166.txt',
#  'OBJ03968_PS3_K3A_NIA0166.json',
#  'OBJ03968_PS3_K3A_NIA0166.txt',
#  'OBJ03972_PS3_K3A_NIA0166.json',
#  'OBJ03972_PS3_K3A_NIA0166.txt',
#  'OBJ03973_PS3_K3A_NIA0166.json',
#  'OBJ03973_PS3_K3A_NIA0166.txt',
#  'OBJ03977_PS3_K3A_NIA0166.json',
#  'OBJ03977_PS3_K3A_NIA0166.txt',
#  'OBJ03984_PS3_K3A_NIA0166.json',
#  'OBJ03984_PS3_K3A_NIA0166.txt',
#  'OBJ03986_PS3_K3A_NIA0166.json',
#  'OBJ03986_PS3_K3A_NIA0166.txt',
#  'OBJ03987_PS3_K3A_NIA0166.json',
#  'OBJ03987_PS3_K3A_NIA0166.txt',
#  'OBJ04093_PS3_K3A_NIA0174.json',
#  'OBJ04093_PS3_K3A_NIA0174.txt',
#  'OBJ04094_PS3_K3A_NIA0174.json',
#  'OBJ04094_PS3_K3A_NIA0174.txt',
#  'OBJ04097_PS3_K3A_NIA0174.json',
#  'OBJ04097_PS3_K3A_NIA0174.txt',
#  'OBJ04098_PS3_K3A_NIA0174.json',
#  'OBJ04098_PS3_K3A_NIA0174.txt',
#  'OBJ04099_PS3_K3A_NIA0174.json',
#  'OBJ04099_PS3_K3A_NIA0174.txt',
#  'OBJ04102_PS3_K3A_NIA0174.json',
#  'OBJ04102_PS3_K3A_NIA0174.txt',
#  'OBJ04104_PS3_K3A_NIA0174.json',
#  'OBJ04104_PS3_K3A_NIA0174.txt',
#  'OBJ04105_PS3_K3A_NIA0174.json',
#  'OBJ04105_PS3_K3A_NIA0174.txt',
#  'OBJ04109_PS3_K3A_NIA0174.json',
#  'OBJ04109_PS3_K3A_NIA0174.txt',
#  'OBJ04110_PS3_K3A_NIA0174.json',
#  'OBJ04110_PS3_K3A_NIA0174.txt',
#  'OBJ04111_PS3_K3A_NIA0174.json',
#  'OBJ04111_PS3_K3A_NIA0174.txt',
#  'OBJ04134_PS3_K3A_NIA0177.json',
#  'OBJ04134_PS3_K3A_NIA0177.txt',
#  'OBJ04135_PS3_K3A_NIA0177.json',
#  'OBJ04135_PS3_K3A_NIA0177.txt',
#  'OBJ04138_PS3_K3A_NIA0177.json',
#  'OBJ04138_PS3_K3A_NIA0177.txt',
#  'OBJ04139_PS3_K3A_NIA0177.json',
#  'OBJ04139_PS3_K3A_NIA0177.txt',
#  'OBJ04151_PS3_K3A_NIA0179.json',
#  'OBJ04151_PS3_K3A_NIA0179.txt',
#  'OBJ04155_PS3_K3A_NIA0179.json',
#  'OBJ04155_PS3_K3A_NIA0179.txt',
#  'OBJ04156_PS3_K3A_NIA0179.json',
#  'OBJ04156_PS3_K3A_NIA0179.txt',
#  'OBJ04157_PS3_K3A_NIA0179.json',
#  'OBJ04157_PS3_K3A_NIA0179.txt',
#  'OBJ04158_PS3_K3A_NIA0179.json',
#  'OBJ04158_PS3_K3A_NIA0179.txt',
#  'OBJ04160_PS3_K3A_NIA0180.json',
#  'OBJ04160_PS3_K3A_NIA0180.txt',
#  'OBJ04169_PS3_K3A_NIA0180.json',
#  'OBJ04169_PS3_K3A_NIA0180.txt',
#  'OBJ04177_PS3_K3A_NIA0180.json',
#  'OBJ04177_PS3_K3A_NIA0180.txt',
#  'OBJ04178_PS3_K3A_NIA0180.json',
#  'OBJ04178_PS3_K3A_NIA0180.txt',
#  'OBJ04179_PS3_K3A_NIA0180.json',
#  'OBJ04179_PS3_K3A_NIA0180.txt',
#  'OBJ04180_PS3_K3A_NIA0180.json',
#  'OBJ04180_PS3_K3A_NIA0180.txt',
#  'OBJ04181_PS3_K3A_NIA0180.json',
#  'OBJ04181_PS3_K3A_NIA0180.txt',
#  'OBJ04192_PS3_K3A_NIA0182.json',
#  'OBJ04192_PS3_K3A_NIA0182.txt',
#  'OBJ04238_PS3_K3_NIA0278.json',
#  'OBJ04238_PS3_K3_NIA0278.txt',
#  'OBJ04293_PS3_K3_NIA0279.json',
#  'OBJ04293_PS3_K3_NIA0279.txt',
#  'OBJ04294_PS3_K3_NIA0279.json',
#  'OBJ04294_PS3_K3_NIA0279.txt',
#  'OBJ04295_PS3_K3_NIA0279.json',
#  'OBJ04295_PS3_K3_NIA0279.txt',
#  'OBJ04296_PS3_K3_NIA0279.json',
#  'OBJ04296_PS3_K3_NIA0279.txt',
#  'OBJ04297_PS3_K3_NIA0279.json',
#  'OBJ04297_PS3_K3_NIA0279.txt',
#  'OBJ04298_PS3_K3_NIA0279.json',
#  'OBJ04298_PS3_K3_NIA0279.txt',
#  'OBJ04299_PS3_K3_NIA0279.json',
#  'OBJ04299_PS3_K3_NIA0279.txt',
#  'OBJ04300_PS3_K3_NIA0279.json',
#  'OBJ04300_PS3_K3_NIA0279.txt',
#  'OBJ04301_PS3_K3_NIA0279.json',
#  'OBJ04301_PS3_K3_NIA0279.txt',
#  'OBJ04302_PS3_K3_NIA0279.json',
#  'OBJ04302_PS3_K3_NIA0279.txt',
#  'OBJ04343_PS3_K3A_NIA0283.json',
#  'OBJ04343_PS3_K3A_NIA0283.txt',
#  'OBJ04348_PS3_K3A_NIA0283.json',
#  'OBJ04348_PS3_K3A_NIA0283.txt',
#  'OBJ04350_PS3_K3A_NIA0283.json',
#  'OBJ04350_PS3_K3A_NIA0283.txt',
#  'OBJ04351_PS3_K3A_NIA0283.json',
#  'OBJ04351_PS3_K3A_NIA0283.txt',
#  'OBJ04352_PS3_K3A_NIA0283.json',
#  'OBJ04352_PS3_K3A_NIA0283.txt',
#  'OBJ04353_PS3_K3A_NIA0283.json',
#  'OBJ04353_PS3_K3A_NIA0283.txt',
#  'OBJ04355_PS3_K3A_NIA0284.json',
#  'OBJ04355_PS3_K3A_NIA0284.txt',
#  'OBJ04356_PS3_K3A_NIA0284.json',
#  'OBJ04356_PS3_K3A_NIA0284.txt',
#  'OBJ04358_PS3_K3A_NIA0284.json',
#  'OBJ04358_PS3_K3A_NIA0284.txt',
#  'OBJ04376_PS3_K3A_NIA0286.json',
#  'OBJ04376_PS3_K3A_NIA0286.txt',
#  'OBJ04385_PS3_K3A_NIA0287.json',
#  'OBJ04385_PS3_K3A_NIA0287.txt',
#  'OBJ04386_PS3_K3A_NIA0287.json',
#  'OBJ04386_PS3_K3A_NIA0287.txt',
#  'OBJ04419_PS3_K3A_NIA0289.json',
#  'OBJ04419_PS3_K3A_NIA0289.txt',
#  'OBJ04476_PS3_K3A_NIA0294.json',
#  'OBJ04476_PS3_K3A_NIA0294.txt',
#  'OBJ04492_PS3_K3A_NIA0296.json',
#  'OBJ04492_PS3_K3A_NIA0296.txt',
#  'OBJ04497_PS3_K3A_NIA0296.json',
#  'OBJ04497_PS3_K3A_NIA0296.txt',
#  'OBJ04503_PS3_K3A_NIA0297.json',
#  'OBJ04503_PS3_K3A_NIA0297.txt',
#  'OBJ04513_PS3_K3A_NIA0298.json',
#  'OBJ04513_PS3_K3A_NIA0298.txt',
#  'OBJ04514_PS3_K3A_NIA0298.json',
#  'OBJ04514_PS3_K3A_NIA0298.txt',
#  'OBJ04515_PS3_K3A_NIA0298.json',
#  'OBJ04515_PS3_K3A_NIA0298.txt',
#  'OBJ04523_PS3_K3A_NIA0299.json',
#  'OBJ04523_PS3_K3A_NIA0299.txt',
#  'OBJ04526_PS3_K3A_NIA0299.json',
#  'OBJ04526_PS3_K3A_NIA0299.txt',
#  'OBJ04527_PS3_K3A_NIA0299.json',
#  'OBJ04527_PS3_K3A_NIA0299.txt',
#  'OBJ04529_PS3_K3A_NIA0299.json',
#  'OBJ04529_PS3_K3A_NIA0299.txt',
#  'OBJ04543_PS3_K3A_NIA0300.json',
#  'OBJ04543_PS3_K3A_NIA0300.txt',
#  'OBJ04546_PS3_K3A_NIA0300.json',
#  'OBJ04546_PS3_K3A_NIA0300.txt',
#  'OBJ04552_PS3_K3A_NIA0300.json',
#  'OBJ04552_PS3_K3A_NIA0300.txt',
#  'OBJ04557_PS3_K3A_NIA0300.json',
#  'OBJ04557_PS3_K3A_NIA0300.txt',
#  'OBJ04559_PS3_K3A_NIA0300.json',
#  'OBJ04559_PS3_K3A_NIA0300.txt',
#  'OBJ04561_PS3_K3A_NIA0300.json',
#  'OBJ04561_PS3_K3A_NIA0300.txt',
#  'OBJ04565_PS3_K3A_NIA0301.json',
#  'OBJ04565_PS3_K3A_NIA0301.txt',
#  'OBJ04589_PS3_K3A_NIA0301.json',
#  'OBJ04589_PS3_K3A_NIA0301.txt',
#  'OBJ04597_PS3_K3A_NIA0302.json',
#  'OBJ04597_PS3_K3A_NIA0302.txt',
#  'OBJ04602_PS3_K3A_NIA0303.json',
#  'OBJ04602_PS3_K3A_NIA0303.txt',
#  'OBJ04603_PS3_K3A_NIA0303.json',
#  'OBJ04603_PS3_K3A_NIA0303.txt',
#  'OBJ04606_PS3_K3A_NIA0303.json',
#  'OBJ04606_PS3_K3A_NIA0303.txt',
#  'OBJ04609_PS3_K3A_NIA0303.json',
#  'OBJ04609_PS3_K3A_NIA0303.txt',
#  'OBJ04610_PS3_K3A_NIA0303.json',
#  'OBJ04610_PS3_K3A_NIA0303.txt',
#  'OBJ04616_PS3_K3A_NIA0303.json',
#  'OBJ04616_PS3_K3A_NIA0303.txt',
#  'OBJ04617_PS3_K3A_NIA0303.json',
#  'OBJ04617_PS3_K3A_NIA0303.txt',
#  'OBJ04620_PS3_K3A_NIA0303.json',
#  'OBJ04620_PS3_K3A_NIA0303.txt',
#  'OBJ04621_PS3_K3A_NIA0303.json',
#  'OBJ04621_PS3_K3A_NIA0303.txt',
#  'OBJ04623_PS3_K3A_NIA0303.json',
#  'OBJ04623_PS3_K3A_NIA0303.txt',
#  'OBJ04624_PS3_K3A_NIA0303.json',
#  'OBJ04624_PS3_K3A_NIA0303.txt',
#  'OBJ04625_PS3_K3A_NIA0303.json',
#  'OBJ04625_PS3_K3A_NIA0303.txt',
#  'OBJ04639_PS3_K3A_NIA0305.json',
#  'OBJ04639_PS3_K3A_NIA0305.txt',
#  'OBJ04640_PS3_K3A_NIA0305.json',
#  'OBJ04640_PS3_K3A_NIA0305.txt',
#  'OBJ04642_PS3_K3A_NIA0306.json',
#  'OBJ04642_PS3_K3A_NIA0306.txt',
#  'OBJ04676_PS3_K3A_NIA0312.json',
#  'OBJ04676_PS3_K3A_NIA0312.txt',
#  'OBJ04679_PS3_K3A_NIA0312.json',
#  'OBJ04679_PS3_K3A_NIA0312.txt',
#  'OBJ04680_PS3_K3A_NIA0312.json',
#  'OBJ04680_PS3_K3A_NIA0312.txt',
#  'OBJ04682_PS3_K3A_NIA0312.json',
#  'OBJ04682_PS3_K3A_NIA0312.txt',
#  'OBJ04763_PS3_K3A_NIA0314.json',
#  'OBJ04763_PS3_K3A_NIA0314.txt',
#  'OBJ04764_PS3_K3A_NIA0314.json',
#  'OBJ04764_PS3_K3A_NIA0314.txt',
#  'OBJ04768_PS3_K3A_NIA0314.json',
#  'OBJ04768_PS3_K3A_NIA0314.txt',
#  'OBJ04769_PS3_K3A_NIA0314.json',
#  'OBJ04769_PS3_K3A_NIA0314.txt',
#  'OBJ04770_PS3_K3A_NIA0314.json',
#  'OBJ04770_PS3_K3A_NIA0314.txt',
#  'OBJ04771_PS3_K3A_NIA0314.json',
#  'OBJ04771_PS3_K3A_NIA0314.txt',
#  'OBJ04773_PS3_K3A_NIA0314.json',
#  'OBJ04773_PS3_K3A_NIA0314.txt',
#  'OBJ04780_PS3_K3A_NIA0297.json',
#  'OBJ04780_PS3_K3A_NIA0297.txt',
#  'OBJ04834_PS3_K3A_NIA0317.json',
#  'OBJ04834_PS3_K3A_NIA0317.txt',
#  'OBJ04835_PS3_K3A_NIA0317.json',
#  'OBJ04835_PS3_K3A_NIA0317.txt',
#  'OBJ04838_PS3_K3A_NIA0317.json',
#  'OBJ04838_PS3_K3A_NIA0317.txt',
#  'OBJ04863_PS3_K3A_NIA0318.json',
#  'OBJ04863_PS3_K3A_NIA0318.txt',
#  'OBJ04895_PS3_K3A_NIA0321.json',
#  'OBJ04895_PS3_K3A_NIA0321.txt',
#  'OBJ04896_PS3_K3A_NIA0321.json',
#  'OBJ04896_PS3_K3A_NIA0321.txt',
#  'OBJ04897_PS3_K3A_NIA0321.json',
#  'OBJ04897_PS3_K3A_NIA0321.txt',
#  'OBJ04921_PS3_K3A_NIA0323.json',
#  'OBJ04921_PS3_K3A_NIA0323.txt',
#  'OBJ04922_PS3_K3A_NIA0172.json',
#  'OBJ04922_PS3_K3A_NIA0172.txt',
#  'OBJ04989_PS3_K3A_NIA0328.json',
#  'OBJ04989_PS3_K3A_NIA0328.txt',
#  'OBJ04993_PS3_K3A_NIA0328.json',
#  'OBJ04993_PS3_K3A_NIA0328.txt',
#  'OBJ04995_PS3_K3A_NIA0328.json',
#  'OBJ04995_PS3_K3A_NIA0328.txt',
#  'OBJ04997_PS3_K3A_NIA0328.json',
#  'OBJ04997_PS3_K3A_NIA0328.txt',
#  'OBJ05005_PS3_K3A_NIA0328.json',
#  'OBJ05005_PS3_K3A_NIA0328.txt',
#  'OBJ05028_PS3_K3A_NIA0329.json',
#  'OBJ05028_PS3_K3A_NIA0329.txt',
#  'OBJ05033_PS3_K3A_NIA0329.json',
#  'OBJ05033_PS3_K3A_NIA0329.txt',
#  'OBJ05035_PS3_K3A_NIA0329.json',
#  'OBJ05035_PS3_K3A_NIA0329.txt',
#  'OBJ05042_PS3_K3A_NIA0329.json',
#  'OBJ05042_PS3_K3A_NIA0329.txt',
#  'OBJ05046_PS3_K3A_NIA0329.json',
#  'OBJ05046_PS3_K3A_NIA0329.txt',
#  'OBJ05048_PS3_K3A_NIA0329.json',
#  'OBJ05048_PS3_K3A_NIA0329.txt',
#  'OBJ05049_PS3_K3A_NIA0329.json',
#  'OBJ05049_PS3_K3A_NIA0329.txt',
#  'OBJ05050_PS3_K3A_NIA0329.json',
#  'OBJ05050_PS3_K3A_NIA0329.txt',
#  'OBJ05051_PS3_K3A_NIA0329.json',
#  'OBJ05051_PS3_K3A_NIA0329.txt',
#  'OBJ05054_PS3_K3A_NIA0329.json',
#  'OBJ05054_PS3_K3A_NIA0329.txt',
#  'OBJ05057_PS3_K3A_NIA0330.json',
#  'OBJ05057_PS3_K3A_NIA0330.txt',
#  'OBJ05058_PS3_K3A_NIA0330.json',
#  'OBJ05058_PS3_K3A_NIA0330.txt',
#  'OBJ05060_PS3_K3A_NIA0330.json',
#  'OBJ05060_PS3_K3A_NIA0330.txt',
#  'OBJ05069_PS3_K3A_NIA0330.json',
#  'OBJ05069_PS3_K3A_NIA0330.txt',
#  'OBJ05070_PS3_K3A_NIA0330.json',
#  'OBJ05070_PS3_K3A_NIA0330.txt',
#  'OBJ05080_PS3_K3A_NIA0331.json',
#  'OBJ05080_PS3_K3A_NIA0331.txt',
#  'OBJ05090_PS3_K3A_NIA0332.json',
#  'OBJ05090_PS3_K3A_NIA0332.txt',
#  'OBJ05103_PS3_K3A_NIA0333.json',
#  'OBJ05103_PS3_K3A_NIA0333.txt',
#  'OBJ05104_PS3_K3A_NIA0333.json',
#  'OBJ05104_PS3_K3A_NIA0333.txt',
#  'OBJ05105_PS3_K3A_NIA0333.json',
#  'OBJ05105_PS3_K3A_NIA0333.txt',
#  'OBJ05109_PS3_K3A_NIA0333.json',
#  'OBJ05109_PS3_K3A_NIA0333.txt',
#  'OBJ05115_PS3_K3A_NIA0333.json',
#  'OBJ05115_PS3_K3A_NIA0333.txt',
#  'OBJ05116_PS3_K3A_NIA0333.json',
#  'OBJ05116_PS3_K3A_NIA0333.txt',
#  'OBJ05119_PS3_K3A_NIA0334.json',
#  'OBJ05119_PS3_K3A_NIA0334.txt',
#  'OBJ05120_PS3_K3A_NIA0334.json',
#  'OBJ05120_PS3_K3A_NIA0334.txt',
#  'OBJ05121_PS3_K3A_NIA0334.json',
#  'OBJ05121_PS3_K3A_NIA0334.txt',
#  'OBJ05135_PS3_K3A_NIA0334.json',
#  'OBJ05135_PS3_K3A_NIA0334.txt',
#  'OBJ05137_PS3_K3A_NIA0334.json',
#  'OBJ05137_PS3_K3A_NIA0334.txt',
#  'OBJ05138_PS3_K3A_NIA0334.json',
#  'OBJ05138_PS3_K3A_NIA0334.txt',
#  'OBJ05141_PS3_K3A_NIA0334.json',
#  'OBJ05141_PS3_K3A_NIA0334.txt',
#  'OBJ05159_PS3_K3A_NIA0336.json',
#  'OBJ05159_PS3_K3A_NIA0336.txt',
#  'OBJ05203_PS3_K3A_NIA0340.json',
#  'OBJ05203_PS3_K3A_NIA0340.txt',
#  'OBJ05205_PS3_K3A_NIA0340.json',
#  'OBJ05205_PS3_K3A_NIA0340.txt',
#  'OBJ05214_PS3_K3A_NIA0340.json',
#  'OBJ05214_PS3_K3A_NIA0340.txt',
#  'OBJ05219_PS3_K3A_NIA0340.json',
#  'OBJ05219_PS3_K3A_NIA0340.txt',
#  'OBJ05220_PS3_K3A_NIA0340.json',
#  'OBJ05220_PS3_K3A_NIA0340.txt',
#  'OBJ05358_PS3_K3A_NIA0346.json',
#  'OBJ05358_PS3_K3A_NIA0346.txt',
#  'OBJ05375_PS3_K3A_NIA0346.json',
#  'OBJ05375_PS3_K3A_NIA0346.txt',
#  'OBJ05376_PS3_K3A_NIA0346.json',
#  'OBJ05376_PS3_K3A_NIA0346.txt',
#  'OBJ05378_PS3_K3A_NIA0346.json',
#  'OBJ05378_PS3_K3A_NIA0346.txt',
#  'OBJ05379_PS3_K3A_NIA0346.json',
#  'OBJ05379_PS3_K3A_NIA0346.txt',
#  'OBJ05382_PS3_K3A_NIA0346.json',
#  'OBJ05382_PS3_K3A_NIA0346.txt',
#  'OBJ05384_PS3_K3A_NIA0346.json',
#  'OBJ05384_PS3_K3A_NIA0346.txt',
#  'OBJ05394_PS3_K3A_NIA0347.json',
#  'OBJ05394_PS3_K3A_NIA0347.txt',
#  'OBJ05401_PS3_K3A_NIA0347.json',
#  'OBJ05401_PS3_K3A_NIA0347.txt',
#  'OBJ05403_PS3_K3A_NIA0347.json',
#  'OBJ05403_PS3_K3A_NIA0347.txt',
#  'OBJ05404_PS3_K3A_NIA0347.json',
#  'OBJ05404_PS3_K3A_NIA0347.txt',
#  'OBJ05408_PS3_K3A_NIA0347.json',
#  'OBJ05408_PS3_K3A_NIA0347.txt',
#  'OBJ05414_PS3_K3A_NIA0349.json',
#  'OBJ05414_PS3_K3A_NIA0349.txt',
#  'OBJ05418_PS3_K3A_NIA0349.json',
#  'OBJ05418_PS3_K3A_NIA0349.txt',
#  'OBJ05421_PS3_K3A_NIA0349.json',
#  'OBJ05421_PS3_K3A_NIA0349.txt',
#  'OBJ05428_PS3_K3A_NIA0350.json',
#  'OBJ05428_PS3_K3A_NIA0350.txt',
#  'OBJ05430_PS3_K3A_NIA0350.json',
#  'OBJ05430_PS3_K3A_NIA0350.txt',
#  'OBJ05431_PS3_K3A_NIA0350.json',
#  'OBJ05431_PS3_K3A_NIA0350.txt',
#  'OBJ05435_PS3_K3A_NIA0165.json',
#  'OBJ05435_PS3_K3A_NIA0165.txt',
#  'OBJ05443_PS3_K3A_NIA0165.json',
#  'OBJ05443_PS3_K3A_NIA0165.txt',
#  'OBJ05445_PS3_K3A_NIA0165.json',
#  'OBJ05445_PS3_K3A_NIA0165.txt',
#  'OBJ05451_PS3_K3A_NIA0166.json',
#  'OBJ05451_PS3_K3A_NIA0166.txt',
#  'OBJ05453_PS3_K3A_NIA0166.json',
#  'OBJ05453_PS3_K3A_NIA0166.txt',
#  'OBJ05457_PS3_K3A_NIA0166.json',
#  'OBJ05457_PS3_K3A_NIA0166.txt',
#  'OBJ05461_PS3_K3A_NIA0166.json',
#  'OBJ05461_PS3_K3A_NIA0166.txt',
#  'OBJ05463_PS3_K3A_NIA0166.json',
#  'OBJ05463_PS3_K3A_NIA0166.txt',
#  'OBJ05464_PS3_K3A_NIA0166.json',
#  'OBJ05464_PS3_K3A_NIA0166.txt',
#  'OBJ05465_PS3_K3A_NIA0166.json',
#  'OBJ05465_PS3_K3A_NIA0166.txt',
#  'OBJ05470_PS3_K3A_NIA0166.json',
#  'OBJ05470_PS3_K3A_NIA0166.txt',
#  'OBJ05475_PS3_K3A_NIA0166.json',
#  'OBJ05475_PS3_K3A_NIA0166.txt',
#  'OBJ05480_PS3_K3A_NIA0166.json',
#  'OBJ05480_PS3_K3A_NIA0166.txt',
#  'OBJ05481_PS3_K3A_NIA0166.json',
#  'OBJ05481_PS3_K3A_NIA0166.txt',
#  'OBJ05483_PS3_K3A_NIA0166.json',
#  'OBJ05483_PS3_K3A_NIA0166.txt',
#  'OBJ05485_PS3_K3A_NIA0166.json',
#  'OBJ05485_PS3_K3A_NIA0166.txt',
#  'OBJ05486_PS3_K3A_NIA0166.json',
#  'OBJ05486_PS3_K3A_NIA0166.txt',
#  'OBJ05487_PS3_K3A_NIA0166.json',
#  'OBJ05487_PS3_K3A_NIA0166.txt',
#  'OBJ05488_PS3_K3A_NIA0166.json',
#  'OBJ05488_PS3_K3A_NIA0166.txt',
#  'OBJ05500_PS3_K3A_NIA0166.json',
#  'OBJ05500_PS3_K3A_NIA0166.txt',
#  'OBJ05504_PS3_K3A_NIA0166.json',
#  'OBJ05504_PS3_K3A_NIA0166.txt',
#  'OBJ05508_PS3_K3A_NIA0166.json',
#  'OBJ05508_PS3_K3A_NIA0166.txt',
#  'OBJ05509_PS3_K3A_NIA0166.json',
#  'OBJ05509_PS3_K3A_NIA0166.txt',
#  'OBJ05530_PS3_K3A_NIA0353.json',
#  'OBJ05530_PS3_K3A_NIA0353.txt',
#  'OBJ05557_PS3_K3A_NIA0355.json',
#  'OBJ05557_PS3_K3A_NIA0355.txt',
#  'OBJ05558_PS3_K3A_NIA0355.json',
#  'OBJ05558_PS3_K3A_NIA0355.txt',
#  'OBJ05559_PS3_K3A_NIA0355.json',
#  'OBJ05559_PS3_K3A_NIA0355.txt',
#  'OBJ05565_PS3_K3A_NIA0355.json',
#  'OBJ05565_PS3_K3A_NIA0355.txt',
#  'OBJ05572_PS3_K3A_NIA0355.json',
#  'OBJ05572_PS3_K3A_NIA0355.txt',
#  'OBJ05574_PS3_K3A_NIA0355.json',
#  'OBJ05574_PS3_K3A_NIA0355.txt',
#  'OBJ05575_PS3_K3A_NIA0355.json',
#  'OBJ05575_PS3_K3A_NIA0355.txt',
#  'OBJ05576_PS3_K3A_NIA0355.json',
#  'OBJ05576_PS3_K3A_NIA0355.txt',
#  'OBJ05590_PS3_K3A_NIA0357.json',
#  'OBJ05590_PS3_K3A_NIA0357.txt',
#  'OBJ05599_PS3_K3A_NIA0357.json',
#  'OBJ05599_PS3_K3A_NIA0357.txt',
#  'OBJ05601_PS3_K3A_NIA0357.json',
#  'OBJ05601_PS3_K3A_NIA0357.txt',
#  'OBJ05614_PS3_K3A_NIA0357.json',
#  'OBJ05614_PS3_K3A_NIA0357.txt',
#  'OBJ05618_PS3_K3A_NIA0358.json',
#  'OBJ05618_PS3_K3A_NIA0358.txt',
#  'OBJ05624_PS3_K3A_NIA0358.json',
#  'OBJ05624_PS3_K3A_NIA0358.txt',
#  'OBJ05625_PS3_K3A_NIA0358.json',
#  'OBJ05625_PS3_K3A_NIA0358.txt',
#  'OBJ05626_PS3_K3A_NIA0358.json',
#  'OBJ05626_PS3_K3A_NIA0358.txt',
#  'OBJ05627_PS3_K3A_NIA0358.json',
#  'OBJ05627_PS3_K3A_NIA0358.txt',
#  'OBJ05652_PS3_K3A_NIA0359.json',
#  'OBJ05652_PS3_K3A_NIA0359.txt',
#  'OBJ05653_PS3_K3A_NIA0359.json',
#  'OBJ05653_PS3_K3A_NIA0359.txt',
#  'OBJ05656_PS3_K3A_NIA0359.json',
#  'OBJ05656_PS3_K3A_NIA0359.txt',
#  'OBJ05664_PS3_K3A_NIA0360.json',
#  'OBJ05664_PS3_K3A_NIA0360.txt',
#  'OBJ05670_PS3_K3A_NIA0360.json',
#  'OBJ05670_PS3_K3A_NIA0360.txt',
#  'OBJ05684_PS3_K3A_NIA0361.json',
#  'OBJ05684_PS3_K3A_NIA0361.txt',
#  'OBJ05685_PS3_K3A_NIA0361.json',
#  'OBJ05685_PS3_K3A_NIA0361.txt',
#  'OBJ05687_PS3_K3A_NIA0361.json',
#  'OBJ05687_PS3_K3A_NIA0361.txt',
#  'OBJ05689_PS3_K3A_NIA0361.json',
#  'OBJ05689_PS3_K3A_NIA0361.txt',
#  'OBJ05690_PS3_K3A_NIA0361.json',
#  'OBJ05690_PS3_K3A_NIA0361.txt',
#  'OBJ05691_PS3_K3A_NIA0361.json',
#  'OBJ05691_PS3_K3A_NIA0361.txt',
#  'OBJ05693_PS3_K3A_NIA0361.json',
#  'OBJ05693_PS3_K3A_NIA0361.txt',
#  'OBJ05702_PS3_K3A_NIA0362.json',
#  'OBJ05702_PS3_K3A_NIA0362.txt',
#  'OBJ05704_PS3_K3A_NIA0362.json',
#  'OBJ05704_PS3_K3A_NIA0362.txt',
#  'OBJ05705_PS3_K3A_NIA0362.json',
#  'OBJ05705_PS3_K3A_NIA0362.txt',
#  'OBJ05706_PS3_K3A_NIA0363.json',
#  'OBJ05706_PS3_K3A_NIA0363.txt',
#  'OBJ05708_PS3_K3A_NIA0363.json',
#  'OBJ05708_PS3_K3A_NIA0363.txt',
#  'OBJ05709_PS3_K3A_NIA0363.json',
#  'OBJ05709_PS3_K3A_NIA0363.txt',
#  'OBJ05731_PS3_K3A_NIA0363.json',
#  'OBJ05731_PS3_K3A_NIA0363.txt',
#  'OBJ05732_PS3_K3A_NIA0363.json',
#  'OBJ05732_PS3_K3A_NIA0363.txt',
#  'OBJ05734_PS3_K3A_NIA0363.json',
#  'OBJ05734_PS3_K3A_NIA0363.txt',
#  'OBJ05827_PS3_K3A_NIA0595.json',
#  'OBJ05827_PS3_K3A_NIA0595.txt',
#  'OBJ05853_PS3_K3_NIA0608.json',
#  'OBJ05853_PS3_K3_NIA0608.txt',
#  'OBJ06280_PS3_K3A_NIA0641.json',
#  'OBJ06280_PS3_K3A_NIA0641.txt',
#  'OBJ07351_PS3_K3A_NIA0786.json',
#  'OBJ07351_PS3_K3A_NIA0786.txt',
#  'OBJ07374_PS3_K3A_NIA0804.json',
#  'OBJ07374_PS3_K3A_NIA0804.txt']

# %%
import os
import shutil
from tqdm import tqdm
import csv

# .json 파일을 기반으로 .png 파일을 찾고, 해당 파일을 바로 복사하는 함수
def get_and_copy_img(json_path, img_path, save_dir):
    # save_dir이 없으면 디렉토리 생성
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    # .json 파일을 기반으로 .png 파일을 찾아서 복사
    for filename in tqdm(os.listdir(json_path), desc="Processing files", unit="file"):
        # .json 파일명을 .png 파일명으로 변환
        png_file = filename.replace('.json', '.png')
        png_file = os.path.join(img_path, png_file).replace('\\', '/')
        
        # .png 파일이 존재하는지 확인하고, 존재하면 복사
        if os.path.exists(png_file):
            shutil.copy(png_file, save_dir)
        else:
            print(f"Warning: {png_file} not found!")

# %%
# 사용 예시
json_train_dir = './datasets/labels/train'  # .json 파일들이 있는 디렉토리
img_train_dir = './train/train_objects_images'  # .png 파일들이 있는 디렉토리
save_dir = './datasets/images/train'  # .png 파일을 복사할 디렉토리

# 출력 폴더가 없으면 생성
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# .json 파일을 기반으로 .png 파일을 찾고 바로 복사
get_and_copy_img(json_train_dir, img_train_dir, save_dir)
# Out:
# Processing files:  13%|█▎        | 93/714 [00:00<00:00, 920.80file/s]
# Warning: ./train/train_objects_images/OBJ00022_PS3_K3_NIA0078.txt not found!
# Warning: ./train/train_objects_images/OBJ00028_PS3_K3_NIA0078.txt not found!
# Warning: ./train/train_objects_images/OBJ00258_PS3_K3_NIA0081.txt not found!
# Warning: ./train/train_objects_images/OBJ00261_PS3_K3_NIA0081.txt not found!
# Warning: ./train/train_objects_images/OBJ00607_PS3_K3_NIA0086.txt not found!
# Warning: ./train/train_objects_images/OBJ01399_PS3_K3_NIA0093.txt not found!
# Warning: ./train/train_objects_images/OBJ01400_PS3_K3_NIA0093.txt not found!
# Warning: ./train/train_objects_images/OBJ01505_PS3_K3_NIA0095.txt not found!
# Warning: ./train/train_objects_images/OBJ01589_PS3_K3_NIA0097.txt not found!
# Warning: ./train/train_objects_images/OBJ01654_PS3_K3_NIA0101.txt not found!
# Warning: ./train/train_objects_images/OBJ01675_PS3_K3_NIA0102.txt not found!
# Warning: ./train/train_objects_images/OBJ01691_PS3_K3_NIA0102.txt not found!
# Warning: ./train/train_objects_images/OBJ01696_PS3_K3_NIA0102.txt not found!
# Warning: ./train/train_objects_images/OBJ01701_PS3_K3_NIA0102.txt not found!
# Warning: ./train/train_objects_images/OBJ01735_PS3_K3_NIA0104.txt not found!
# Warning: ./train/train_objects_images/OBJ01937_PS3_K3_NIA0110.txt not found!
# Warning: ./train/train_objects_images/OBJ02050_PS3_K3_NIA0112.txt not found!
# Warning: ./train/train_objects_images/OBJ05664_PS3_K3A_NIA0360.txt not found!
# Warning: ./train/train_objects_images/OBJ05670_PS3_K3A_NIA0360.txt not found!
# Warning: ./train/train_objects_images/OBJ05684_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05685_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05687_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05689_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05690_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05691_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05693_PS3_K3A_NIA0361.txt not found!
# Warning: ./train/train_objects_images/OBJ05702_PS3_K3A_NIA0362.txt not found!
# Warning: ./train/train_objects_images/OBJ05704_PS3_K3A_NIA0362.txt not found!
# Warning: ./train/train_objects_images/OBJ05705_PS3_K3A_NIA0362.txt not found!
# Warning: ./train/train_objects_images/OBJ05706_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05708_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05709_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05731_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05732_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05734_PS3_K3A_NIA0363.txt not found!
# Warning: ./train/train_objects_images/OBJ05827_PS3_K3A_NIA0595.txt not found!
# Warning: ./train/train_objects_images/OBJ05853_PS3_K3_NIA0608.txt not found!
# Warning: ./train/train_objects_images/OBJ06280_PS3_K3A_NIA0641.txt not found!
# Warning: ./train/train_objects_images/OBJ07351_PS3_K3A_NIA0786.txt not found!
# Warning: ./train/train_objects_images/OBJ07374_PS3_K3A_NIA0804.txt not found!

# %%
# 사용 예시
json_train_dir = './datasets/labels/val'  # .json 파일들이 있는 디렉토리
img_train_dir = './valid/vaildate_objects_images'  # .png 파일들이 있는 디렉토리
save_dir = './datasets/images/val'  # .png 파일을 복사할 디렉토리



# 출력 폴더가 없으면 생성
if not os.path.exists(save_dir):
    os.makedirs(save_dir)


# .json 파일을 기반으로 .png 파일을 찾고 바로 복사
get_and_copy_img(json_train_dir, img_train_dir, save_dir)
# Out:
# Processing files:   0%|          | 0/74 [00:00<?, ?file/s]
# Warning: ./valid/vaildate_objects_images/OBJ01526_PS3_K3_NIA0095.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ01673_PS3_K3_NIA0102.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ01925_PS3_K3_NIA0110.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ02127_PS3_K3_NIA0113.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ02310_PS3_K3_NIA0118.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ02833_PS3_K3_NIA0126.txt not found!
# Warning: ./valid/vaildate_objects_images/OBJ03445_PS3_K3A_NIA0139.txt not found!
    for filename in tqdm(os.listdir(json_path), desc="Processing files", unit="file"):
        # .json 파일명을 .png 파일명으로 변환
        json_file = os.path.join(json_path, filename).replace('\\', '/')
        png_file = filename.replace('.json', '.png')
        png_file = os.path.join(img_path, png_file).replace('\\', '/')

        # .png 파일이 실제로 존재하는지 확인 후 리스트에 추가
        if os.path.exists(png_file):
            img_json_list.append([png_file, json_file])
        else:
            print(f"Warning: {png_file} not found!")

    return img_json_list

# 추출된 경로 리스트를 CSV 파일로 저장하는 함수
def save_to_csv(data, output_csv):
    # CSV 파일로 저장
    with open(output_csv, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # 헤더 작성
        writer.writerow(["Image", "JSON"])
        # 데이터 작성
        writer.writerows(data)

# %%
# 사용 예시
label_dir = './datasets/labels/train'  # .json 파일들이 있는 디렉토리
img_dir = './datasets/images/train'  # .png 파일들이 있는 디렉토리
output_csv = 'train.csv'  # 경로 정보를 저장할 CSV 파일명

# .json과 .png 경로 추출
img_json_list = get_img_json_list(label_dir, img_dir)

# 경로 정보를 CSV 파일로 저장
save_to_csv(img_json_list, output_csv)
# Out:
# Processing files: 100%|██████████| 714/714 [00:00<00:00, 20999.02file/s]
# Warning: ./datasets/images/train/OBJ00022_PS3_K3_NIA0078.txt not found!
# Warning: ./datasets/images/train/OBJ00028_PS3_K3_NIA0078.txt not found!
# Warning: ./datasets/images/train/OBJ00258_PS3_K3_NIA0081.txt not found!
# Warning: ./datasets/images/train/OBJ00261_PS3_K3_NIA0081.txt not found!
# Warning: ./datasets/images/train/OBJ00607_PS3_K3_NIA0086.txt not found!
# Warning: ./datasets/images/train/OBJ01399_PS3_K3_NIA0093.txt not found!
# Warning: ./datasets/images/train/OBJ01400_PS3_K3_NIA0093.txt not found!
# Warning: ./datasets/images/train/OBJ01505_PS3_K3_NIA0095.txt not found!
# Warning: ./datasets/images/train/OBJ01589_PS3_K3_NIA0097.txt not found!
# Warning: ./datasets/images/train/OBJ01654_PS3_K3_NIA0101.txt not found!
# Warning: ./datasets/images/train/OBJ01675_PS3_K3_NIA0102.txt not found!
# Warning: ./datasets/images/train/OBJ01691_PS3_K3_NIA0102.txt not found!
# Warning: ./datasets/images/train/OBJ01696_PS3_K3_NIA0102.txt not found!
# Warning: ./datasets/images/train/OBJ01701_PS3_K3_NIA0102.txt not found!
# Warning: ./datasets/images/train/OBJ01735_PS3_K3_NIA0104.txt not found!
# Warning: ./datasets/images/train/OBJ01937_PS3_K3_NIA0110.txt not found!
# Warning: ./datasets/images/train/OBJ02050_PS3_K3_NIA0112.txt not found!
# Warning: ./datasets/images/train/OBJ02293_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/train/OBJ02297_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/train/OBJ02307_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/train/OBJ02311_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/train/OBJ02314_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/train/OBJ05734_PS3_K3A_NIA0363.txt not found!
# Warning: ./datasets/images/train/OBJ05827_PS3_K3A_NIA0595.txt not found!
# Warning: ./datasets/images/train/OBJ05853_PS3_K3_NIA0608.txt not found!
# Warning: ./datasets/images/train/OBJ06280_PS3_K3A_NIA0641.txt not found!
# Warning: ./datasets/images/train/OBJ07351_PS3_K3A_NIA0786.txt not found!
# Warning: ./datasets/images/train/OBJ07374_PS3_K3A_NIA0804.txt not found!

# %%
# 사용 예시
label_dir = './datasets/labels/val'  # .json 파일들이 있는 디렉토리
img_dir = './datasets/images/val'  # .png 파일들이 있는 디렉토리
output_csv = 'valid.csv'  # 경로 정보를 저장할 CSV 파일명

# .json과 .png 경로 추출
img_json_list = get_img_json_list(label_dir, img_dir)

# 경로 정보를 CSV 파일로 저장
save_to_csv(img_json_list, output_csv)
# Out:
# Processing files: 100%|██████████| 74/74 [00:00<00:00, 5285.92file/s]
# Warning: ./datasets/images/val/OBJ01526_PS3_K3_NIA0095.txt not found!
# Warning: ./datasets/images/val/OBJ01673_PS3_K3_NIA0102.txt not found!
# Warning: ./datasets/images/val/OBJ01925_PS3_K3_NIA0110.txt not found!
# Warning: ./datasets/images/val/OBJ02127_PS3_K3_NIA0113.txt not found!
# Warning: ./datasets/images/val/OBJ02310_PS3_K3_NIA0118.txt not found!
# Warning: ./datasets/images/val/OBJ02833_PS3_K3_NIA0126.txt not found!
# Warning: ./datasets/images/val/OBJ03445_PS3_K3A_NIA0139.txt not found!
# Warning: ./datasets/images/val/OBJ03705_PS3_K3A_NIA0156.txt not found!
# Warning: ./datasets/images/val/OBJ03721_PS3_K3A_NIA0156.txt not found!
# Warning: ./datasets/images/val/OBJ03722_PS3_K3A_NIA0156.txt not found!
# Warning: ./datasets/images/val/OBJ03725_PS3_K3A_NIA0156.txt not found!
# Warning: ./datasets/images/val/OBJ03735_PS3_K3A_NIA0156.txt not found!
# Warning: ./datasets/images/val/OBJ03800_PS3_K3A_NIA0159.txt not found!
# Warning: ./datasets/images/val/OBJ03803_PS3_K3A_NIA0159.txt not found!
# Warning: ./datasets/images/val/OBJ03942_PS3_K3A_NIA0166.txt not found!
# Warning: ./datasets/images/val/OBJ03962_PS3_K3A_NIA0166.txt not found!
# Warning: ./datasets/images/val/OBJ03974_PS3_K3A_NIA0166.txt not found!
# Warning: ./datasets/images/val/OBJ04100_PS3_K3A_NIA0174.txt not found!
# Warning: ./datasets/images/val/OBJ04166_PS3_K3A_NIA0180.txt not found!
# Warning: ./datasets/images/val/OBJ04528_PS3_K3A_NIA0299.txt not found!
# Warning: ./datasets/images/val/OBJ04553_PS3_K3A_NIA0300.txt not found!
# Warning: ./datasets/images/val/OBJ04605_PS3_K3A_NIA0303.txt not found!
# Warning: ./datasets/images/val/OBJ04643_PS3_K3A_NIA0306.txt not found!
# Warning: ./datasets/images/val/OBJ04778_PS3_K3A_NIA0297.txt not found!
# Warning: ./datasets/images/val/OBJ04814_PS3_K3A_NIA0315.txt not found!
# Warning: ./datasets/images/val/OBJ04837_PS3_K3A_NIA0317.txt not found!
# Warning: ./datasets/images/val/OBJ05134_PS3_K3A_NIA0334.txt not found!
# Warning: ./datasets/images/val/OBJ05377_PS3_K3A_NIA0346.txt not found!
# Warning: ./datasets/images/val/OBJ05413_PS3_K3A_NIA0349.txt not found!
# Warning: ./datasets/images/val/OBJ05417_PS3_K3A_NIA0349.txt not found!
# Warning: ./datasets/images/val/OBJ05437_PS3_K3A_NIA0165.txt not found!
# Warning: ./datasets/images/val/OBJ05444_PS3_K3A_NIA0165.txt not found!
# Warning: ./datasets/images/val/OBJ05449_PS3_K3A_NIA0165.txt not found!
# Warning: ./datasets/images/val/OBJ05502_PS3_K3A_NIA0166.txt not found!
# Warning: ./datasets/images/val/OBJ05616_PS3_K3A_NIA0358.txt not found!
# Warning: ./datasets/images/val/OBJ05716_PS3_K3A_NIA0363.txt not found!
# Warning: ./datasets/images/val/OBJ05783_PS3_K3A_NIA0368.txt not found!

# %%
import os
import csv
import json
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.patches as patches
import numpy as np

# 유클리드 거리 계산 함수
def euclidean_distance(p1, p2):
    return np.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

# JSON 파일을 읽어들이는 함수 (BBox 좌표와 angle 포함)
def get_bbox_from_json(json_file):
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    results = []
    
    if 'features' in data:
        for feature in data['features']:
            if 'properties' in feature:
                # object_imcoords를 파싱하여 좌표 추출
                imcoords = feature['properties'].get('object_imcoords', '')
                if imcoords:
                    coords = list(map(float, imcoords.split(',')))
                    

                    results.append(coords)
    
    return results

# 바운딩 박스 정보를 txt 파일로 저장하는 함수
def save_bbox_to_txt(coord_list, output_file):
    with open(output_file, 'w') as f:
        for coord in coord_list:
            x1,y1,x2,y2,x3,y3,x4,y4 = coord/1024
            
            f.write(f"0 {x1:.6f} {y1:.6f} {x2:.6f} {y2:.6f} {x3:.6f} {y3:.6f} {x4:.6f} {y4:.6f}\n")

# CSV에서 이미지 경로와 JSON 경로를 불러오는 함수
def load_csv(csv_path):
    data = []
    with open(csv_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # 헤더 스킵
        for row in reader:
            img_path, json_path = row
            data.append((img_path, json_path))
    return data

# 사용 예시
csv_path = 'train.csv'  # CSV 파일 경로
data = load_csv(csv_path)  # 이미지와 JSON 경로 불러오기

# %%
import os
import csv
import json
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.patches as patches
import numpy as np

# 유클리드 거리 계산 함수
def euclidean_distance(p1, p2):
    return np.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

# JSON 파일을 읽어들이는 함수 (BBox 좌표와 angle 포함)
def get_bbox_from_json(json_file):
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    results = []
    
    if 'features' in data:
        for feature in data['features']:
            if 'properties' in feature:
                # object_imcoords를 파싱하여 좌표 추출
                imcoords = feature['properties'].get('object_imcoords', '')
                if imcoords:
                    coords = list(map(float, imcoords.split(',')))
                    coords = np.array(coords).reshape(-1, 2)  # 2D 좌표로 변환

                    # 중심 좌표 계산
                    cx = np.mean(coords[:, 0])
                    cy = np.mean(coords[:, 1])

                    # 인접한 두 점으로부터 너비와 높이 계산
                    width = euclidean_distance(coords[0], coords[1])
                    height = euclidean_distance(coords[1], coords[2])

                    # 각도 추출
                    angle = feature['properties'].get('object_angle', 0.0)

                    # 회전된 바운딩 박스 좌표 저장 (cx, cy, width, height, angle)
                    results.append((cx, cy, width, height, angle))

    return results

# 이미지와 바운딩 박스를 시각화하는 함수
def visualize_image_with_bbox(image_path, bbox_list):
    # 이미지를 불러오기
    img = Image.open(image_path)
    fig, ax = plt.subplots(1)
    ax.imshow(img)

    # 바운딩 박스 그리기
    for bbox in bbox_list:
        cx, cy, width, height, angle = bbox

        # 바운딩 박스 좌표 계산 (중심 기준으로 회전)
        rect_coords = [
            [-width / 2, -height / 2],  # 좌상단
            [width / 2, -height / 2],   # 우상단
            [width / 2, height / 2],    # 우하단
            [-width / 2, height / 2]    # 좌하단
        ]

        # 회전 각도를 라디안으로 변환하여 회전 행렬 적용
        theta = np.radians(angle)
        theta = -theta  # 이미지에서 반시계 방향으로 회전하기 때문에 부호 반전
        rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])
        rotated_coords = np.dot(rect_coords, rotation_matrix)

        # 중심 좌표로 평행 이동
        rotated_coords[:, 0] += cx
        rotated_coords[:, 1] += cy

        # 회전된 좌표를 Polygon으로 시각화
        polygon = patches.Polygon(rotated_coords, closed=True, linewidth=2, edgecolor='r', facecolor='none')
        ax.add_patch(polygon)
    
    plt.axis('off')
    plt.show()

# CSV에서 이미지 경로와 JSON 경로를 불러오는 함수
def load_csv(csv_path):
    data = []
    with open(csv_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # 헤더 스킵
        for row in reader:
            img_path, json_path = row
            data.append((img_path, json_path))
    return data

# 사용 예시
csv_path = 'train.csv'  # CSV 파일 경로
data = load_csv(csv_path)  # 이미지와 JSON 경로 불러오기

# 5개의 이미지와 바운딩 박스를 시각화
for i, (img_path, json_path) in enumerate(data):
    if i >= 5:
        break
    if os.path.exists(img_path) and os.path.exists(json_path):
        bbox_list = get_bbox_from_json(json_path)  # JSON에서 BBox 추출
        visualize_image_with_bbox(img_path, bbox_list)  # 이미지와 BBox 시각화

# %%
# 사용 예시
csv_path = 'valid.csv'  # CSV 파일 경로
data = load_csv(csv_path)  # 이미지와 JSON 경로 불러오기

# 5개의 이미지와 바운딩 박스를 시각화
for i, (img_path, json_path) in enumerate(data):
    if i >= 5:
        break
    if os.path.exists(img_path) and os.path.exists(json_path):
        bbox_list = get_bbox_from_json(json_path)  # JSON에서 BBox 추출
        visualize_image_with_bbox(img_path, bbox_list)  # 이미지와 BBox 시각화
